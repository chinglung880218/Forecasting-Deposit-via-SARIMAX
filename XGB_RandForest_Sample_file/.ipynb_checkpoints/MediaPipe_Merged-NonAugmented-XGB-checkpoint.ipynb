# %% [markdown]
# Download FER-2013 from Kaggle

# %%
pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (1.6.17)
# Requirement already satisfied: six>=1.10 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from kaggle) (1.16.0)
# Requirement already satisfied: certifi>=2023.7.22 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from kaggle) (2024.8.30)
# Requirement already satisfied: python-dateutil in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: requests in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from kaggle) (2.32.3)
# Requirement already satisfied: tqdm in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from kaggle) (4.66.5)
# Requirement already satisfied: python-slugify in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from kaggle) (5.0.2)
# Requirement already satisfied: urllib3 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from kaggle) (2.2.3)
# Requirement already satisfied: bleach in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from kaggle) (4.1.0)
# Requirement already satisfied: packaging in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from bleach->kaggle) (24.1)
# Requirement already satisfied: webencodings in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from requests->kaggle) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from requests->kaggle) (3.7)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
# Specify the directory to save the dataset
save_directory_data = os.path.expanduser('~/Downloads')
os.makedirs(save_directory_data, exist_ok=True)
# Download the dataset
os.system(f'kaggle datasets download -d msambare/fer2013 -p "{save_directory_data}"')
# Out:
# Dataset URL: https://www.kaggle.com/datasets/msambare/fer2013
# License(s): DbCL-1.0
# fer2013.zip: Skipping, found more recently modified local copy (use --force to force download)
# 0

# %%
import cv2
import matplotlib.pyplot as plt
import random
from collections import Counter
import numpy as np
import pandas as pd
import random
from torchvision import transforms
from PIL import Image
from sklearn.model_selection import train_test_split
import shutil
from sklearn.preprocessing import LabelEncoder
from skimage import exposure
import os
import matplotlib.pyplot as plt
import mediapipe as mp
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf
from sklearn.model_selection import KFold, cross_val_score
from sklearn.svm import SVC

# %%
# Directory paths
train_dir = os.path.expanduser('/Users/sherrywang/Desktop/fer2013/train')
test_dir = os.path.expanduser('/Users/sherrywang/Desktop/fer2013/test')

# %%
# Define a function to load data
def load_images_from_directory(directory):
    images = []
    labels = []
    for label in os.listdir(directory):
        label_path = os.path.join(directory, label)
        if os.path.isdir(label_path):
            for file in os.listdir(label_path):
                file_path = os.path.join(label_path, file)
                image = cv2.imread(file_path, cv2.IMREAD_GRAYSCALE)
                images.append(image)
                labels.append(label)
    return images, labels

# Load training and testing images
train_images, train_labels = load_images_from_directory(train_dir)
test_images, test_labels = load_images_from_directory(test_dir)

print(f"Loaded {len(train_images)} training images and {len(test_images)} testing images.")
# Out:
# Loaded 28709 training images and 7178 testing images.

# %%
# Define a function to count the number of images in each category
def count_images_per_category(labels, dataset_label):
    category_counts = Counter(labels)
    total_images = len(labels)
    
    # Print the counts for each category
    print(f"\n{dataset_label} set:")
    for category, count in category_counts.items():
        print(f"Category '{category}': {count} images")
    
    print(f"Total number of images in {dataset_label} set: {total_images}")
    return category_counts, total_images

# Count images in training and testing
train_counts, num_train_images = count_images_per_category(train_labels, "Training")
test_counts, num_test_images = count_images_per_category(test_labels, "Testing")
# Out:
# Training set:
# Category 'happy': 7215 images
# Category 'sad': 4830 images
# Category 'fear': 4097 images
# Category 'surprise': 3171 images
# Category 'neutral': 4965 images
# Category 'angry': 3995 images
# Category 'disgust': 436 images
# Total number of images in Training set: 28709
#
# Testing set:
# Category 'happy': 1774 images
# Category 'sad': 1247 images
# Category 'fear': 1024 images
# Category 'surprise': 831 images
# Category 'neutral': 1233 images
# Category 'angry': 958 images
# Category 'disgust': 111 images
# Total number of images in Testing set: 7178

# %% [markdown]
# Visualzie Random Samples from Each Category

# %%
# Define a function to visualize random samples from each category
def visualize_samples(images, labels, num_samples=5, dataset_label="Dataset"):
    unique_labels = set(labels)
    
    for label in unique_labels:
        label_images = [img for img, lbl in zip(images, labels) if lbl == label]
        
        print(f"Label: {label}")
        sample_images = random.sample(label_images, min(num_samples, len(label_images)))
        
        plt.figure(figsize=(15, 3))
        for i, image in enumerate(sample_images):
            plt.subplot(1, num_samples, i + 1)
            plt.imshow(image, cmap='gray')
            plt.title(label)
            plt.axis('off')
        
        plt.show()

# Visualize samples from training and testing
visualize_samples(train_images, train_labels, num_samples=5, dataset_label="Training")
visualize_samples(test_images, test_labels, num_samples=5, dataset_label="Testing")
# Out:
# Label: disgust
# Label: neutral
# Label: fear
# Label: happy
# Label: sad
# Label: angry
# Label: surprise
# Label: disgust
# Label: neutral
# Label: fear
# Label: happy
# Label: sad
# Label: angry
# Label: surprise

# %% [markdown]
# Data Cleaning

# %%
# Define a function to check if images are loaded correctly and correct size
def check_images(images, labels, dataset_label="Dataset"):
    invalid_images = []
    for i, image in enumerate(images):
        if image is None or image.shape != (48, 48):
            print(f"Invalid image detected in {dataset_label} set: Label - {labels[i]}, Index - {i}")
            invalid_images.append((labels[i], i))  # Store label and index of invalid images
    print(f"Total invalid images in {dataset_label} set: {len(invalid_images)}")

# Check the training and testing sets in memory
check_images(train_images, train_labels, dataset_label="Training")
check_images(test_images, test_labels, dataset_label="Testing")
# Out:
# Total invalid images in Training set: 0
# Total invalid images in Testing set: 0

# %% [markdown]
# Addressing Data Imbalance: Step 1 Downsample 'happy' to 5000 Images

# %% [markdown]
# Addressing Data Imbalance: Step 2 Augmentation

# %% [markdown]
# Count the Number of Images in Each Category

# %%
# Load training balanced dataset
train_images, train_labels = load_images_from_directory(train_dir)
test_images, test_labels = load_images_from_directory(test_dir)
# Count images in training balanced dataset
train_counts, num_train_images = count_images_per_category(train_labels, "Training")
# Out:
# Training set:
# Category 'happy': 7215 images
# Category 'sad': 4830 images
# Category 'fear': 4097 images
# Category 'surprise': 3171 images
# Category 'neutral': 4965 images
# Category 'angry': 3995 images
# Category 'disgust': 436 images
# Total number of images in Training set: 28709

# %% [markdown]
# Feature Extraction for Training Balanced Dataset

# %%
mp_face_mesh = mp.solutions.face_mesh
face_mesh = mp_face_mesh.FaceMesh(static_image_mode=True, max_num_faces=1, refine_landmarks=True)  


def extract_mediapipe_features(image, label_images):
 
    """
    Extract facial landmarks using MediaPipe Face Mesh. If no face is detected,
    continually retry with a randomly selected and augmented image from the same label.
    
    Parameters:
    - image: The initial input image to extract features from.
    - label_images: List of images under the same label to select from if retry is needed.
    
    Returns:
    - feature_vector: List of landmark (x, y, z) coordinates.
    """

    while True:
        # Ensure image is of type uint8 (0-255 range)
        image_uint8 = np.array(image, dtype=np.uint8)
        
        # Convert to RGB if grayscale
        if len(image_uint8.shape) == 2:  # Grayscale image
            image_rgb = cv2.cvtColor(image_uint8, cv2.COLOR_GRAY2RGB)
        else:
            image_rgb = image_uint8
        
        # Verify and re-cast to ensure MediaPipe compatibility
        image_rgb = np.array(image_rgb, dtype=np.uint8)
        #print("Image shape after conversion:", image_rgb.shape, "Data type:", image_rgb.dtype)
        
        # Process with MediaPipe Face Mesh
        results = face_mesh.process(image_rgb)
        
        if results.multi_face_landmarks:
            # Extract landmark coordinates for the detected face
            feature_vector = []
            for landmark in results.multi_face_landmarks[0].landmark:
                x, y, z = landmark.x, landmark.y, landmark.z
                #flattened 1d features
                feature_vector.extend([x, y, z]) 
                #feature_vector.append([x, y, z])
            return feature_vector  # Return feature vector if landmarks are detected
        
        # If no face is detected, print message and retry with augmented image
        print("No face detected in the image. Retrying with augmented image...")
        image = random.choice(label_images)  # Randomly choose a new image from the same label


# Process each category separately
train_features = []
test_features = []
for label in set(train_labels):  # Iterate over each unique label
    # Filter images and labels for the current label
    label_images = [img for img, lbl in zip(train_images, train_labels) if lbl == label]
    
    # Process each image in the current label category
    for i, image in enumerate(label_images):
        #print(f"Processing image {i+1}/{len(label_images)} for label '{label}'")
        feature_vector = extract_mediapipe_features(image, label_images)  # Pass both image and label_images
        if feature_vector is not None:
            train_features.append(feature_vector)

print("Feature extraction completed.")

for label in set(test_labels):  # Iterate over each unique label
    # Filter images and labels for the current label
    label_images = [img for img, lbl in zip(test_images, test_labels) if lbl == label]
    
    # Process each image in the current label category
    for i, image in enumerate(label_images):
        #print(f"Processing image {i+1}/{len(label_images)} for label '{label}'")
        feature_vector = extract_mediapipe_features(image, label_images)  # Pass both image and label_images
        if feature_vector is not None:
            test_features.append(feature_vector)

print("Feature extraction completed.")


# Encode labels
label_encoder = LabelEncoder()
train_labels_encoded = label_encoder.fit_transform(train_labels)

# Specify the directory to save extracted features and encoded labels
save_directory_features = os.path.expanduser('~/Downloads/fer2013/ExtractedFeatures_media')
os.makedirs(save_directory_features, exist_ok=True)

# Save MediaPipe features and encoded labels
np.save(f'{save_directory_features}/train_Media.npy', train_features)
np.save(f'{save_directory_features}/train_labels_encoded_Media.npy', train_labels_encoded)
print("Features and labels saved successfully.")
# Out:
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1731875533.463257 3342374 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88.1), renderer: Apple M3
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# W0000 00:00:1731875533.474144 3342740 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1731875533.477942 3342740 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1731875533.480144 3342740 landmark_projection_calculator.cc:186] Using NORM_RECT without IMAGE_DIMENSIONS is only supported for the square ROI. Provide IMAGE_DIMENSIONS or use PROJECTION_MATRIX.
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# ...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# Feature extraction completed.
# Features and labels saved successfully.

# %%
    """# Load HOG features and encoded labels
train_features = np.load(f'{save_directory_features}/train_Media.npy')
train_labels_encoded = np.load(f'{save_directory_features}/train_labels_encoded_Media.npy')
print("Features and labels loaded successfully.")

# Print the shape of train_features
print("Shape of train MediaPipe features:", train_features.shape)
    """
# Out:
# '# Load HOG features and encoded labels\ntrain_features = np.load(f\'{save_directory_features}/train_Media.npy\')\ntrain_labels_encoded = np.load(f\'{save_directory_features}/train_labels_encoded_Media.npy\')\nprint("Features and labels loaded successfully.")\n\n# Print the shape of train_features\nprint("Shape of train MediaPipe features:", train_features.shape)\n'

# %%
# Load training balanced dataset
test_images, test_labels = load_images_from_directory(test_dir)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV, cross_val_predict, cross_val_score, KFold, StratifiedKFold, train_test_split
from sklearn.metrics import classification_report

# %%
# Standardize the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(train_features)

# Apply PCA to reduce dimensionality
pca = PCA(n_components=15)
X_train_pca = pca.fit_transform(X_train_scaled)

# Check the amount of variance explained by the components
explained_variance = np.sum(pca.explained_variance_ratio_)
print(f"Explained variance with {pca.n_components_} components: {explained_variance:.2f}")
# Out:
# Explained variance with 15 components: 1.00

# %%
from xgboost import XGBClassifier

# %%
test_scaled_features = scaler.fit_transform(test_features)

# Apply PCA
transformed_features_test = pca.fit_transform(test_scaled_features)

# %%
# Assuming you have your data as X and y

def auto_xgboost(
    X,
    y,
    n_estimators=100,
    random_state=2024,
    cv=10
):
    # 1. Parameter grid
    param_grid = {
        'max_depth': [3, 5, 10, 20, 30],
        'learning_rate': [0.01, 0.1, 0.3],
        'min_child_weight': [1, 2, 5, 10, 20, 30, 40]
        # 'gamma': [0, 0.1],
        # 'subsample': [0.8, 1.0],
        # 'colsample_bytree': [0.8, 1.0]
    }
    # 2. Create base model
    xgb_model = XGBClassifier(
        objective='multi:softmax',
        n_estimators= n_estimators,
        # use_label_encoder=False,
        eval_metric='merror',
        random_state=random_state
    )

    # 3. Setup StratifiedKFold
    skf = StratifiedKFold(
        n_splits=cv,
        shuffle=True,
        random_state=random_state
    )

    # 4. Setup GridSearchCV
    grid_search = GridSearchCV(
        estimator=xgb_model,
        param_grid=param_grid,
        cv=skf,
        scoring='accuracy',
        n_jobs=-1, # use all the CPU cores
        verbose=2  # detailed output monitoring progress updates
    )

    # 5. Scale the features
    label_encoder = LabelEncoder()
    y_encoded = label_encoder.fit_transform(y)
    
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)

    # 6. Fit the model
    grid_search.fit(X_scaled, y_encoded)

    # 7. Best model
    best_model = grid_search.best_estimator_
    
    # 8. Best params
    best_par = grid_search.best_params_
    
    # 9. Best CV score
    best_score = grid_search.best_score_

    # 10. Feature importance
    feature_importance = pd.DataFrame({
        'feature': [f'feature_{i}' for i in range(X.shape[1])],
        'importance': best_model.feature_importances_
    })
    feature_importance = feature_importance.sort_values('importance', ascending=False)
    
    # compile and return the results
    results = {
        'best_params': best_par,
        'best_score': best_score,
        'best_model': best_model,
        'feature_importance': feature_importance
    }

    return results, grid_search

# %%
XGB_result, grid_search = auto_xgboost(X=X_train_pca, y=train_labels_encoded )

# loop through and print the results
for key, value in XGB_result.items():
    print(f"{key}: \n {value}")
# Out:
# Fitting 10 folds for each of 105 candidates, totalling 1050 fits
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1; total time=   0.9s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=2; total time=   0.9s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=2; total time=   0.9s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=5; total time=   0.9s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=10; total time=   0.8s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=20; total time=   0.8s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=30; total time=   0.9s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=30; total time=   0.9s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=40; total time=   0.9s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1; total time=   1.8s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=2; total time=   1.8s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=2; total time=   1.7s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=5; total time=   1.7s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=10; total time=   1.7s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=20; total time=   1.7s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=30; total time=   1.7s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=30; total time=   1.7s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=40; total time=   1.6s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=1; total time=  14.5s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=2; total time=  13.0s
# /Users/sherrywang/anaconda3/lib/python3.12/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1; total time=   0.9s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=2; total time=   0.9s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=5; total time=   0.8s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=10; total time=   0.8s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=10; total time=   0.9s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=20; total time=   0.8s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=30; total time=   0.9s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=40; total time=   0.8s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=40; total time=   0.9s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1; total time=   1.8s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=2; total time=   1.8s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=5; total time=   1.7s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=5; total time=   1.8s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=10; total time=   1.7s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=20; total time=   1.6s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=30; total time=   1.7s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=40; total time=   1.7s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=40; total time=   1.7s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=1; total time=  14.5s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=2; total time=  13.0s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1; total time=   0.9s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1; total time=   0.9s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=2; total time=   0.9s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=5; total time=   0.9s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=10; total time=   0.8s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=20; total time=   0.9s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=30; total time=   0.9s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=40; total time=   0.8s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=40; total time=   1.0s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1; total time=   1.8s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=2; total time=   1.8s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=5; total time=   1.8s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=10; total time=   1.7s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=10; total time=   1.7s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=20; total time=   1.7s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=30; total time=   1.6s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=40; total time=   1.6s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=1; total time=  14.1s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=1; total time=  14.9s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=5; total time=  10.0s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1; total time=   0.9s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=2; total time=   0.9s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=5; total time=   0.9s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=5; total time=   0.8s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=10; total time=   0.8s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=20; total time=   0.8s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=20; total time=   0.9s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=30; total time=   0.9s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=40; total time=   0.9s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1; total time=   1.8s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=2; total time=   1.8s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=2; total time=   1.8s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=5; total time=   1.7s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=10; total time=   1.7s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=20; total time=   1.7s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=30; total time=   1.7s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=40; total time=   1.7s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=1; total time=  14.4s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=1; total time=  14.7s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=5; total time=  10.2s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1; total time=   0.9s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=2; total time=   0.9s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=2; total time=   0.9s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=5; total time=   0.9s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=10; total time=   0.9s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=20; total time=   0.9s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=30; total time=   0.9s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=40; total time=   0.9s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1; total time=   1.8s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1; total time=   1.8s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=2; total time=   1.8s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=5; total time=   1.7s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=10; total time=   1.6s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=20; total time=   1.6s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=20; total time=   1.7s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=30; total time=   1.8s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=40; total time=   1.7s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=1; total time=  14.4s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=2; total time=  13.1s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=2; total time=  12.7s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1; total time=   0.9s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=2; total time=   0.8s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=5; total time=   0.9s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=5; total time=   0.9s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=10; total time=   0.9s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=20; total time=   0.9s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=30; total time=   0.8s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=30; total time=   0.9s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=40; total time=   0.9s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1; total time=   1.8s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=2; total time=   1.8s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=5; total time=   1.7s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=5; total time=   1.7s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=10; total time=   1.7s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=20; total time=   1.7s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=30; total time=   1.6s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=30; total time=   1.7s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=40; total time=   1.6s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=1; total time=  14.6s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=2; total time=  12.9s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=2; total time=  12.7s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1; total time=   0.8s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1; total time=   0.8s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=2; total time=   0.9s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=5; total time=   0.9s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=10; total time=   0.9s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=20; total time=   0.9s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=20; total time=   0.9s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=30; total time=   0.9s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=40; total time=   1.0s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1; total time=   1.8s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=2; total time=   1.8s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=5; total time=   1.8s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=10; total time=   1.7s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=10; total time=   1.7s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=20; total time=   1.7s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=30; total time=   1.7s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=40; total time=   1.7s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=40; total time=   1.6s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=1; total time=  14.4s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=2; total time=  12.9s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=2; total time=  13.0s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1; total time=   0.9s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=2; total time=   0.9s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=5; total time=   0.8s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=10; total time=   0.9s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=10; total time=   0.9s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=20; total time=   0.9s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=30; total time=   0.8s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=40; total time=   0.9s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1; total time=   2.1s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1; total time=   1.8s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=2; total time=   1.8s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=5; total time=   1.8s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=10; total time=   1.8s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=20; total time=   1.7s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=20; total time=   1.7s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=30; total time=   1.7s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=40; total time=   1.6s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=1; total time=  14.7s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=2; total time=  12.9s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=2; total time=  13.3s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=5; total time=   9.8s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=10; total time=   8.0s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=20; total time=   5.8s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=30; total time=   4.6s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=40; total time=   4.0s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=1; total time=  51.5s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=10; total time=   7.6s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=10; total time=   8.1s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=20; total time=   5.8s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=30; total time=   4.7s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=30; total time=   4.6s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=40; total time=   4.1s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=1; total time=  52.4s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=5; total time=  10.1s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=5; total time=   9.8s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=10; total time=   8.0s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=20; total time=   6.0s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=30; total time=   4.8s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=30; total time=   4.7s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=40; total time=   4.0s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=1; total time=  51.1s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=2; total time=  38.0s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=5; total time=   9.8s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=10; total time=   8.0s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=20; total time=   5.9s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=20; total time=   5.6s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=40; total time=   4.1s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=40; total time=   4.1s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=1; total time=  51.5s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=2; total time=  37.4s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=2; total time=  37.2s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=5; total time=  10.1s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=5; total time=   9.9s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=10; total time=   8.1s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=20; total time=   5.9s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=30; total time=   4.7s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=30; total time=   4.6s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=40; total time=   4.1s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=1; total time=  51.9s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=2; total time=  37.2s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=2; total time=  37.2s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=5; total time=  21.0s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=10; total time=   7.6s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=10; total time=   7.9s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=20; total time=   5.9s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=30; total time=   4.7s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=30; total time=   4.6s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=40; total time=   4.1s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=1; total time=  51.4s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=2; total time=  37.5s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=2; total time=  37.1s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=5; total time=  20.7s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=20; total time=   8.0s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=5; total time=   9.9s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=10; total time=   8.1s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=20; total time=   5.7s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=30; total time=   4.5s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=40; total time=   3.9s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=1; total time=  51.9s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=1; total time=  50.9s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=5; total time=  21.2s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=5; total time=  21.0s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=10; total time=  13.1s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=20; total time=   7.9s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=30; total time=   5.8s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=40; total time=   4.8s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=40; total time=   4.8s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=1; total time=  55.9s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=20; total time=   7.6s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=30; total time=   5.7s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=40; total time=   4.6s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=40; total time=   4.8s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=1; total time=  56.5s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=20; total time=   7.8s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=20; total time=   7.7s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=30; total time=   5.8s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=40; total time=   4.6s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=1; total time=  56.5s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=1; total time=  56.1s
# best_params:
#  {'learning_rate': 0.1, 'max_depth': 20, 'min_child_weight': 2}
# best_score:
#  0.4473854245931621
# best_model:
#  XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='merror',
#               feature_types=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=20,
#               max_leaves=None, min_child_weight=2, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=100,
#               n_jobs=None, num_parallel_tree=None, objective='multi:softmax', ...)
# feature_importance:
#         feature  importance
# 6    feature_6    0.116464
# 7    feature_7    0.099703
# 8    feature_8    0.072721
# 13  feature_13    0.070978
# 9    feature_9    0.068690
# 11  feature_11    0.062027
# 12  feature_12    0.061579
# 3    feature_3    0.059090
# 1    feature_1    0.057268
# 2    feature_2    0.056936
# 4    feature_4    0.055792
# 0    feature_0    0.055529
# 5    feature_5    0.054687
# 10  feature_10    0.054602
# 14  feature_14    0.053934
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=2; total time=  37.6s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=5; total time=  20.9s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=5; total time=  21.3s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=10; total time=  13.0s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=10; total time=  13.0s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=20; total time=   7.9s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=30; total time=   5.9s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=40; total time=   4.8s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=1; total time=  56.2s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=2; total time=  40.3s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=2; total time=  40.0s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=10; total time=  13.8s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=10; total time=  13.4s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=20; total time=   8.2s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=30; total time=   6.0s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=30; total time=   6.1s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=40; total time=   4.8s
# [CV] END .learning_rate=0.1, max_depth=3, min_child_weight=2; total time=   0.9s
# [CV] END .learning_rate=0.1, max_depth=3, min_child_weight=5; total time=   1.0s
# [CV] END .learning_rate=0.1, max_depth=3, min_child_weight=5; total time=   1.0s
# [CV] END learning_rate=0.1, max_depth=3, min_child_weight=10; total time=   0.9s
# [CV] END learning_rate=0.1, max_depth=3, min_child_weight=20; total time=   1.0s
# [CV] END learning_rate=0.1, max_depth=3, min_child_weight=30; total time=   0.9s
# [CV] END learning_rate=0.1, max_depth=3, min_child_weight=40; total time=   0.9s
# [CV] END learning_rate=0.1, max_depth=3, min_child_weight=40; total time=   0.9s
# [CV] END .learning_rate=0.1, max_depth=5, min_child_weight=1; total time=   1.8s
# [CV] END .learning_rate=0.1, max_depth=5, min_child_weight=2; total time=   1.9s
# [CV] END .learning_rate=0.1, max_depth=5, min_child_weight=5; total time=   1.8s
# [CV] END learning_rate=0.1, max_depth=5, min_child_weight=10; total time=   1.7s
# [CV] END learning_rate=0.1, max_depth=5, min_child_weight=10; total time=   1.6s
# [CV] END learning_rate=0.1, max_depth=5, min_child_weight=20; total time=   1.6s
# [CV] END learning_rate=0.1, max_depth=5, min_child_weight=30; total time=   1.5s
# [CV] END learning_rate=0.1, max_depth=5, min_child_weight=40; total time=   1.5s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=1; total time=  10.4s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=1; total time=  10.4s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=5; total time=   6.9s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=5; total time=   6.9s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=10; total time=   5.4s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=20; total time=   3.9s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=30; total time=   3.5s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=30; total time=   3.2s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=40; total time=   3.0s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=1; total time=  32.1s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=2; total time=  23.4s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=2; total time=  23.5s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=10; total time=   9.6s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=10; total time=   9.7s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=20; total time=   6.4s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=30; total time=   5.2s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=30; total time=   5.0s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=40; total time=   4.3s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=1; total time=  35.5s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=2; total time=  26.2s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=5; total time=  16.6s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=5; total time=  16.5s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=10; total time=  10.9s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=20; total time=   7.3s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=20; total time=   7.3s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=30; total time=   5.7s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=40; total time=   4.7s
# [CV] END .learning_rate=0.3, max_depth=3, min_child_weight=1; total time=   0.9s
# [CV] END .learning_rate=0.3, max_depth=3, min_child_weight=1; total time=   1.0s
# [CV] END .learning_rate=0.3, max_depth=3, min_child_weight=2; total time=   0.9s
# [CV] END .learning_rate=0.3, max_depth=3, min_child_weight=2; total time=   0.9s
# [CV] END .learning_rate=0.3, max_depth=3, min_child_weight=5; total time=   0.9s
# [CV] END learning_rate=0.3, max_depth=3, min_child_weight=10; total time=   0.9s
# [CV] END learning_rate=0.3, max_depth=3, min_child_weight=20; total time=   0.9s
# [CV] END learning_rate=0.3, max_depth=3, min_child_weight=30; total time=   0.9s
# [CV] END learning_rate=0.3, max_depth=3, min_child_weight=30; total time=   0.9s
# [CV] END learning_rate=0.3, max_depth=3, min_child_weight=40; total time=   0.9s
# [CV] END .learning_rate=0.3, max_depth=5, min_child_weight=1; total time=   1.8s
# [CV] END .learning_rate=0.3, max_depth=5, min_child_weight=2; total time=   1.7s
# [CV] END .learning_rate=0.3, max_depth=5, min_child_weight=5; total time=   1.6s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=10; total time=   1.5s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=10; total time=   1.5s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=20; total time=   1.5s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=30; total time=   1.4s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=40; total time=   1.2s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1; total time=   8.5s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1; total time=   8.8s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=5; total time=   5.6s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=5; total time=   5.6s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=10; total time=   4.3s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=20; total time=   3.2s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=30; total time=   2.8s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=30; total time=   2.9s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=40; total time=   2.7s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=1; total time=  17.9s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=2; total time=  13.3s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=5; total time=   9.1s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=5; total time=   9.0s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=10; total time=   7.1s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=20; total time=   5.2s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=20; total time=   5.0s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=30; total time=   4.2s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=40; total time=   3.8s
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=1; total time=  20.2s
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=2; total time=  14.3s
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=2; total time=  14.5s
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=5; total time=   9.9s
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=10; total time=   7.6s
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=20; total time=   5.8s
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=30; total time=   4.8s
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=40; total time=   4.1s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=2; total time=  40.1s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=5; total time=  22.3s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=5; total time=  21.8s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=10; total time=  13.4s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=20; total time=   8.0s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=20; total time=   7.9s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=30; total time=   6.0s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=40; total time=   4.9s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=40; total time=   4.8s
# [CV] END .learning_rate=0.1, max_depth=3, min_child_weight=1; total time=   0.9s
# [CV] END .learning_rate=0.1, max_depth=3, min_child_weight=2; total time=   1.0s
# [CV] END .learning_rate=0.1, max_depth=3, min_child_weight=2; total time=   0.9s
# [CV] END .learning_rate=0.1, max_depth=3, min_child_weight=5; total time=   0.9s
# [CV] END learning_rate=0.1, max_depth=3, min_child_weight=10; total time=   0.9s
# [CV] END learning_rate=0.1, max_depth=3, min_child_weight=20; total time=   0.9s
# [CV] END learning_rate=0.1, max_depth=3, min_child_weight=30; total time=   0.9s
# [CV] END learning_rate=0.1, max_depth=3, min_child_weight=30; total time=   0.9s
# [CV] END learning_rate=0.1, max_depth=3, min_child_weight=40; total time=   0.9s
# [CV] END .learning_rate=0.1, max_depth=5, min_child_weight=1; total time=   1.7s
# [CV] END .learning_rate=0.1, max_depth=5, min_child_weight=2; total time=   1.7s
# [CV] END .learning_rate=0.1, max_depth=5, min_child_weight=2; total time=   1.7s
# [CV] END .learning_rate=0.1, max_depth=5, min_child_weight=5; total time=   1.7s
# [CV] END learning_rate=0.1, max_depth=5, min_child_weight=10; total time=   1.6s
# [CV] END learning_rate=0.1, max_depth=5, min_child_weight=20; total time=   1.5s
# [CV] END learning_rate=0.1, max_depth=5, min_child_weight=30; total time=   1.5s
# [CV] END learning_rate=0.1, max_depth=5, min_child_weight=30; total time=   1.4s
# [CV] END learning_rate=0.1, max_depth=5, min_child_weight=40; total time=   1.5s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=1; total time=  10.7s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=2; total time=   9.1s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=2; total time=   9.1s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=5; total time=   6.8s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=10; total time=   5.3s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=20; total time=   3.8s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=30; total time=   3.3s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=40; total time=   2.9s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=1; total time=  32.3s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=1; total time=  31.9s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=5; total time=  14.7s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=5; total time=  14.5s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=10; total time=   9.6s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=20; total time=   6.2s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=30; total time=   4.9s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=40; total time=   4.2s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=40; total time=   4.4s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=1; total time=  35.5s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=2; total time=  25.7s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=5; total time=  16.6s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=5; total time=  16.5s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=10; total time=  10.8s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=20; total time=   7.1s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=20; total time=   7.3s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=30; total time=   5.5s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=40; total time=   4.6s
# [CV] END .learning_rate=0.3, max_depth=3, min_child_weight=1; total time=   0.9s
# [CV] END .learning_rate=0.3, max_depth=3, min_child_weight=1; total time=   0.9s
# [CV] END .learning_rate=0.3, max_depth=3, min_child_weight=2; total time=   0.8s
# [CV] END .learning_rate=0.3, max_depth=3, min_child_weight=2; total time=   0.9s
# [CV] END .learning_rate=0.3, max_depth=3, min_child_weight=5; total time=   0.9s
# [CV] END learning_rate=0.3, max_depth=3, min_child_weight=10; total time=   0.8s
# [CV] END learning_rate=0.3, max_depth=3, min_child_weight=20; total time=   0.9s
# [CV] END learning_rate=0.3, max_depth=3, min_child_weight=20; total time=   0.9s
# [CV] END learning_rate=0.3, max_depth=3, min_child_weight=30; total time=   0.9s
# [CV] END learning_rate=0.3, max_depth=3, min_child_weight=40; total time=   0.9s
# [CV] END .learning_rate=0.3, max_depth=5, min_child_weight=1; total time=   1.7s
# [CV] END .learning_rate=0.3, max_depth=5, min_child_weight=1; total time=   1.7s
# [CV] END .learning_rate=0.3, max_depth=5, min_child_weight=2; total time=   1.6s
# [CV] END .learning_rate=0.3, max_depth=5, min_child_weight=5; total time=   1.6s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=10; total time=   1.5s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=20; total time=   1.4s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=20; total time=   1.4s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=30; total time=   1.4s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=40; total time=   1.3s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1; total time=   8.6s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=2; total time=   7.1s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=2; total time=   7.2s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=5; total time=   5.5s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=10; total time=   4.2s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=20; total time=   3.1s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=30; total time=   2.7s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=40; total time=   2.5s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=1; total time=  17.8s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=1; total time=  17.8s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=5; total time=   9.0s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=5; total time=   8.9s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=10; total time=   6.9s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=20; total time=   5.2s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=30; total time=   4.2s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=40; total time=   3.7s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=40; total time=   3.9s
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=1; total time=  20.1s
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=2; total time=  14.4s
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=2; total time=  14.2s
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=5; total time=   9.9s
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=10; total time=   7.5s
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=20; total time=   5.7s
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=30; total time=   4.7s
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=40; total time=   4.2s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=2; total time=  40.2s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=5; total time=  22.0s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=5; total time=  21.9s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=10; total time=  13.4s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=10; total time=  13.3s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=20; total time=   8.1s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=30; total time=   5.8s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=40; total time=   4.9s
# [CV] END .learning_rate=0.1, max_depth=3, min_child_weight=1; total time=   1.0s
# [CV] END .learning_rate=0.1, max_depth=3, min_child_weight=1; total time=   0.9s
# [CV] END .learning_rate=0.1, max_depth=3, min_child_weight=2; total time=   0.9s
# [CV] END .learning_rate=0.1, max_depth=3, min_child_weight=5; total time=   0.9s
# [CV] END learning_rate=0.1, max_depth=3, min_child_weight=10; total time=   0.9s
# [CV] END learning_rate=0.1, max_depth=3, min_child_weight=10; total time=   0.9s
# [CV] END learning_rate=0.1, max_depth=3, min_child_weight=20; total time=   0.9s
# [CV] END learning_rate=0.1, max_depth=3, min_child_weight=30; total time=   0.9s
# [CV] END learning_rate=0.1, max_depth=3, min_child_weight=40; total time=   0.9s
# [CV] END learning_rate=0.1, max_depth=3, min_child_weight=40; total time=   0.9s
# [CV] END .learning_rate=0.1, max_depth=5, min_child_weight=1; total time=   1.7s
# [CV] END .learning_rate=0.1, max_depth=5, min_child_weight=2; total time=   1.7s
# [CV] END .learning_rate=0.1, max_depth=5, min_child_weight=5; total time=   1.7s
# [CV] END learning_rate=0.1, max_depth=5, min_child_weight=10; total time=   1.6s
# [CV] END learning_rate=0.1, max_depth=5, min_child_weight=10; total time=   1.6s
# [CV] END learning_rate=0.1, max_depth=5, min_child_weight=20; total time=   1.5s
# [CV] END learning_rate=0.1, max_depth=5, min_child_weight=30; total time=   1.4s
# [CV] END learning_rate=0.1, max_depth=5, min_child_weight=40; total time=   1.4s
# [CV] END learning_rate=0.1, max_depth=5, min_child_weight=40; total time=   1.5s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=1; total time=  10.6s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=2; total time=   9.2s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=5; total time=   6.9s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=5; total time=   6.9s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=10; total time=   5.3s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=20; total time=   3.9s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=20; total time=   3.9s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=30; total time=   3.3s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=40; total time=   3.1s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=1; total time=  32.0s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=2; total time=  23.6s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=2; total time=  23.3s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=5; total time=  14.4s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=10; total time=   9.9s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=20; total time=   6.5s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=30; total time=   4.9s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=40; total time=   4.4s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=1; total time=  35.4s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=2; total time=  25.9s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=2; total time=  25.8s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=5; total time=  16.2s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=10; total time=  10.9s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=20; total time=   7.4s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=30; total time=   5.5s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=40; total time=   4.7s
# [CV] END .learning_rate=0.3, max_depth=3, min_child_weight=1; total time=   0.9s
# [CV] END .learning_rate=0.3, max_depth=3, min_child_weight=1; total time=   0.9s
# [CV] END .learning_rate=0.3, max_depth=3, min_child_weight=2; total time=   0.9s
# [CV] END .learning_rate=0.3, max_depth=3, min_child_weight=5; total time=   0.9s
# [CV] END learning_rate=0.3, max_depth=3, min_child_weight=10; total time=   0.9s
# [CV] END learning_rate=0.3, max_depth=3, min_child_weight=20; total time=   0.9s
# [CV] END learning_rate=0.3, max_depth=3, min_child_weight=20; total time=   0.9s
# [CV] END learning_rate=0.3, max_depth=3, min_child_weight=30; total time=   0.9s
# [CV] END learning_rate=0.3, max_depth=3, min_child_weight=40; total time=   0.9s
# [CV] END .learning_rate=0.3, max_depth=5, min_child_weight=1; total time=   1.8s
# [CV] END .learning_rate=0.3, max_depth=5, min_child_weight=2; total time=   1.7s
# [CV] END .learning_rate=0.3, max_depth=5, min_child_weight=2; total time=   1.7s
# [CV] END .learning_rate=0.3, max_depth=5, min_child_weight=5; total time=   1.6s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=10; total time=   1.5s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=20; total time=   1.4s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=30; total time=   1.3s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=30; total time=   1.3s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=40; total time=   1.3s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1; total time=   8.6s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=2; total time=   7.2s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=2; total time=   7.3s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=5; total time=   5.4s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=10; total time=   4.1s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=20; total time=   3.1s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=30; total time=   2.8s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=40; total time=   2.5s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=1; total time=  18.1s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=1; total time=  17.7s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=5; total time=   9.1s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=5; total time=   9.1s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=10; total time=   7.0s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=20; total time=   5.1s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=30; total time=   4.4s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=40; total time=   3.8s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=40; total time=   3.9s
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=1; total time=  20.1s
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=2; total time=  14.5s
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=5; total time=  10.2s
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=5; total time=   9.8s
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=10; total time=   7.8s
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=20; total time=   5.8s
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=20; total time=   5.5s
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=30; total time=   4.6s
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=40; total time=   3.7s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=10; total time=  12.9s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=10; total time=  12.8s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=20; total time=   7.6s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=30; total time=   5.7s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=30; total time=   5.7s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=40; total time=   4.8s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=1; total time=  56.1s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=2; total time=  40.4s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=2; total time=  39.8s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=5; total time=  21.9s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=20; total time=   8.1s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=20; total time=   8.1s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=30; total time=   6.2s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=40; total time=   5.0s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=40; total time=   4.7s
# [CV] END .learning_rate=0.1, max_depth=3, min_child_weight=2; total time=   1.0s
# [CV] END .learning_rate=0.1, max_depth=3, min_child_weight=5; total time=   0.9s
# [CV] END learning_rate=0.1, max_depth=3, min_child_weight=10; total time=   0.9s
# [CV] END learning_rate=0.1, max_depth=3, min_child_weight=20; total time=   0.9s
# [CV] END learning_rate=0.1, max_depth=3, min_child_weight=20; total time=   1.0s
# [CV] END learning_rate=0.1, max_depth=3, min_child_weight=30; total time=   0.9s
# [CV] END learning_rate=0.1, max_depth=3, min_child_weight=40; total time=   0.9s
# [CV] END .learning_rate=0.1, max_depth=5, min_child_weight=1; total time=   1.8s
# [CV] END .learning_rate=0.1, max_depth=5, min_child_weight=2; total time=   1.7s
# [CV] END .learning_rate=0.1, max_depth=5, min_child_weight=5; total time=   1.7s
# [CV] END .learning_rate=0.1, max_depth=5, min_child_weight=5; total time=   1.8s
# [CV] END learning_rate=0.1, max_depth=5, min_child_weight=10; total time=   1.7s
# [CV] END learning_rate=0.1, max_depth=5, min_child_weight=20; total time=   1.6s
# [CV] END learning_rate=0.1, max_depth=5, min_child_weight=30; total time=   1.5s
# ...
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=5; total time=  22.0s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=10; total time=  13.3s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=20; total time=   8.0s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=30; total time=   6.2s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=40; total time=   4.8s
# [CV] END .learning_rate=0.1, max_depth=3, min_child_weight=1; total time=   0.9s
# [CV] END .learning_rate=0.1, max_depth=3, min_child_weight=2; total time=   0.9s
# [CV] END .learning_rate=0.1, max_depth=3, min_child_weight=5; total time=   1.0s
# [CV] END learning_rate=0.1, max_depth=3, min_child_weight=10; total time=   0.9s
# [CV] END learning_rate=0.1, max_depth=3, min_child_weight=20; total time=   1.0s
# [CV] END learning_rate=0.1, max_depth=3, min_child_weight=20; total time=   0.9s
# [CV] END learning_rate=0.1, max_depth=3, min_child_weight=30; total time=   0.9s
# [CV] END learning_rate=0.1, max_depth=3, min_child_weight=40; total time=   0.9s
# [CV] END .learning_rate=0.1, max_depth=5, min_child_weight=1; total time=   1.8s
# [CV] END .learning_rate=0.1, max_depth=5, min_child_weight=2; total time=   1.7s
# [CV] END .learning_rate=0.1, max_depth=5, min_child_weight=2; total time=   1.7s
# [CV] END .learning_rate=0.1, max_depth=5, min_child_weight=5; total time=   1.7s
# [CV] END learning_rate=0.1, max_depth=5, min_child_weight=10; total time=   1.6s
# [CV] END learning_rate=0.1, max_depth=5, min_child_weight=20; total time=   1.6s
# [CV] END learning_rate=0.1, max_depth=5, min_child_weight=20; total time=   1.5s
# [CV] END learning_rate=0.1, max_depth=5, min_child_weight=30; total time=   1.5s
# [CV] END learning_rate=0.1, max_depth=5, min_child_weight=40; total time=   1.4s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=1; total time=  10.6s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=2; total time=   9.1s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=2; total time=   9.4s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=10; total time=   5.4s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=10; total time=   5.3s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=20; total time=   4.0s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=30; total time=   3.3s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=40; total time=   2.9s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=40; total time=   2.9s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=1; total time=  32.3s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=2; total time=  23.6s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=2; total time=  23.5s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=10; total time=   9.6s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=10; total time=   9.7s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=20; total time=   6.5s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=30; total time=   4.9s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=30; total time=   4.9s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=40; total time=   4.3s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=1; total time=  35.4s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=2; total time=  26.0s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=2; total time=  25.7s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=10; total time=  11.2s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=10; total time=  10.9s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=20; total time=   7.2s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=30; total time=   5.7s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=30; total time=   5.5s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=40; total time=   4.6s
# [CV] END .learning_rate=0.3, max_depth=3, min_child_weight=1; total time=   0.9s
# [CV] END .learning_rate=0.3, max_depth=3, min_child_weight=2; total time=   0.9s
# [CV] END .learning_rate=0.3, max_depth=3, min_child_weight=5; total time=   0.9s
# [CV] END learning_rate=0.3, max_depth=3, min_child_weight=10; total time=   0.9s
# [CV] END learning_rate=0.3, max_depth=3, min_child_weight=10; total time=   0.9s
# [CV] END learning_rate=0.3, max_depth=3, min_child_weight=20; total time=   0.8s
# [CV] END learning_rate=0.3, max_depth=3, min_child_weight=30; total time=   0.9s
# [CV] END learning_rate=0.3, max_depth=3, min_child_weight=40; total time=   0.9s
# [CV] END learning_rate=0.3, max_depth=3, min_child_weight=40; total time=   0.8s
# [CV] END .learning_rate=0.3, max_depth=5, min_child_weight=1; total time=   1.7s
# [CV] END .learning_rate=0.3, max_depth=5, min_child_weight=2; total time=   1.7s
# [CV] END .learning_rate=0.3, max_depth=5, min_child_weight=5; total time=   1.6s
# [CV] END .learning_rate=0.3, max_depth=5, min_child_weight=5; total time=   1.6s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=10; total time=   1.6s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=20; total time=   1.4s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=30; total time=   1.4s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=40; total time=   1.4s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1; total time=   8.5s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1; total time=   8.6s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=5; total time=   5.5s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=5; total time=   5.5s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=10; total time=   4.4s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=20; total time=   3.2s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=20; total time=   3.1s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=40; total time=   2.5s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=40; total time=   2.7s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=1; total time=  18.0s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=2; total time=  13.1s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=2; total time=  12.9s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=5; total time=   9.0s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=10; total time=   7.1s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=20; total time=   5.2s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=30; total time=   4.3s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=40; total time=   3.7s
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=1; total time=  20.1s
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=1; total time=  19.9s
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=5; total time=  10.0s
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=5; total time=   9.8s
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=10; total time=   7.6s
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=20; total time=   5.7s
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=30; total time=   4.8s
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=40; total time=   4.1s
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=40; total time=   3.5s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=1; total time=  51.3s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=5; total time=  21.5s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=5; total time=  21.1s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=10; total time=  13.2s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=20; total time=   8.0s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=30; total time=   5.9s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=40; total time=   4.8s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=1; total time=  56.0s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=1; total time=  55.8s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=5; total time=  22.5s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=5; total time=  22.2s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=10; total time=  13.3s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=20; total time=   7.9s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=30; total time=   5.9s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=40; total time=   4.9s
# [CV] END .learning_rate=0.1, max_depth=3, min_child_weight=1; total time=   0.9s
# [CV] END .learning_rate=0.1, max_depth=3, min_child_weight=1; total time=   1.0s
# [CV] END .learning_rate=0.1, max_depth=3, min_child_weight=1; total time=   1.0s
# [CV] END .learning_rate=0.1, max_depth=3, min_child_weight=2; total time=   0.8s
# [CV] END .learning_rate=0.1, max_depth=3, min_child_weight=5; total time=   0.9s
# [CV] END learning_rate=0.1, max_depth=3, min_child_weight=10; total time=   0.9s
# [CV] END learning_rate=0.1, max_depth=3, min_child_weight=10; total time=   0.9s
# [CV] END learning_rate=0.1, max_depth=3, min_child_weight=20; total time=   0.9s
# [CV] END learning_rate=0.1, max_depth=3, min_child_weight=30; total time=   0.9s
# [CV] END learning_rate=0.1, max_depth=3, min_child_weight=40; total time=   0.9s
# [CV] END .learning_rate=0.1, max_depth=5, min_child_weight=1; total time=   1.8s
# [CV] END .learning_rate=0.1, max_depth=5, min_child_weight=1; total time=   1.9s
# [CV] END .learning_rate=0.1, max_depth=5, min_child_weight=2; total time=   1.8s
# [CV] END .learning_rate=0.1, max_depth=5, min_child_weight=5; total time=   1.7s
# [CV] END learning_rate=0.1, max_depth=5, min_child_weight=10; total time=   1.7s
# [CV] END learning_rate=0.1, max_depth=5, min_child_weight=20; total time=   1.6s
# [CV] END learning_rate=0.1, max_depth=5, min_child_weight=30; total time=   1.4s
# [CV] END learning_rate=0.1, max_depth=5, min_child_weight=30; total time=   1.4s
# [CV] END learning_rate=0.1, max_depth=5, min_child_weight=40; total time=   1.5s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=1; total time=  10.5s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=2; total time=   9.1s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=2; total time=   9.3s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=10; total time=   5.3s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=10; total time=   5.3s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=20; total time=   4.1s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=30; total time=   3.3s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=30; total time=   3.2s
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=40; total time=   3.1s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=1; total time=  32.3s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=2; total time=  23.4s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=5; total time=  14.7s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=5; total time=  14.3s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=10; total time=   9.6s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=20; total time=   6.3s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=20; total time=   6.3s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=30; total time=   4.9s
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=40; total time=   4.3s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=1; total time=  35.6s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=1; total time=  34.9s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=5; total time=  16.5s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=5; total time=  16.2s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=10; total time=  10.9s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=20; total time=   7.2s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=30; total time=   5.9s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=40; total time=   4.6s
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=40; total time=   4.6s
# [CV] END .learning_rate=0.3, max_depth=3, min_child_weight=2; total time=   0.9s
# [CV] END .learning_rate=0.3, max_depth=3, min_child_weight=5; total time=   0.9s
# [CV] END learning_rate=0.3, max_depth=3, min_child_weight=10; total time=   0.9s
# [CV] END learning_rate=0.3, max_depth=3, min_child_weight=20; total time=   0.9s
# [CV] END learning_rate=0.3, max_depth=3, min_child_weight=30; total time=   0.9s
# [CV] END learning_rate=0.3, max_depth=3, min_child_weight=30; total time=   0.9s
# [CV] END learning_rate=0.3, max_depth=3, min_child_weight=40; total time=   0.8s
# [CV] END .learning_rate=0.3, max_depth=5, min_child_weight=1; total time=   1.8s
# [CV] END .learning_rate=0.3, max_depth=5, min_child_weight=2; total time=   1.7s
# [CV] END .learning_rate=0.3, max_depth=5, min_child_weight=5; total time=   1.6s
# [CV] END .learning_rate=0.3, max_depth=5, min_child_weight=5; total time=   1.6s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=10; total time=   1.5s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=20; total time=   1.4s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=30; total time=   1.3s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=30; total time=   1.3s
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=40; total time=   1.3s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=1; total time=   8.7s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=2; total time=   7.2s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=2; total time=   7.6s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=10; total time=   4.4s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=10; total time=   4.2s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=20; total time=   3.2s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=30; total time=   2.9s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=40; total time=   2.5s
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=40; total time=   2.7s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=1; total time=  17.9s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=2; total time=  12.9s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=2; total time=  13.2s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=10; total time=   7.0s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=10; total time=   7.1s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=20; total time=   5.2s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=30; total time=   4.3s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=30; total time=   4.2s
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=40; total time=   3.9s
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=1; total time=  20.0s
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=2; total time=  14.5s
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=2; total time=  14.7s
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=10; total time=   7.8s
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=10; total time=   7.6s
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=20; total time=   5.8s
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=30; total time=   4.8s
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=30; total time=   4.7s
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=40; total time=   3.3s

# %%
import numpy as np

xgb = XGBClassifier(
    base_score=None, booster=None, callbacks=None,
    colsample_bylevel=None, colsample_bynode=None,
    colsample_bytree=None, device=None, early_stopping_rounds=None,
    enable_categorical=False, eval_metric='merror',
    feature_types=None, gamma=None, grow_policy=None,
    importance_type=None, interaction_constraints=None,
    learning_rate=0.1, max_bin=None, max_cat_threshold=None,
    max_cat_to_onehot=None, max_delta_step=None, max_depth=20,
    max_leaves=None, min_child_weight=2, missing=np.nan,  # Use np.nan
    monotone_constraints=None, multi_strategy=None, n_estimators=100,
    n_jobs=None, num_parallel_tree=None, objective='multi:softmax'
)

xgb.fit(X_train_pca, train_labels_encoded)
test_Class_pred = xgb.predict(transformed_features_test)
print(classification_report(test_labels_encoded, test_Class_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.55      0.52      0.54       958
#            1       0.08      0.01      0.02       111
#            2       0.47      0.60      0.53      1024
#            3       0.43      0.67      0.53      1774
#            4       0.34      0.31      0.33      1233
#            5       0.29      0.18      0.22      1247
#            6       0.30      0.11      0.16       831
#
#     accuracy                           0.42      7178
#    macro avg       0.35      0.34      0.33      7178
# weighted avg       0.39      0.42      0.39      7178

# %%
xgb.fit(X=X_train_pca, y=train_labels_encoded)

train_pred = xgb.predict(X_train_pca)
print(classification_report(train_labels_encoded, train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95      3995
#            1       0.92      0.70      0.80       436
#            2       0.97      0.99      0.98      4097
#            3       0.98      0.98      0.98      7215
#            4       0.93      0.97      0.95      4965
#            5       0.96      0.94      0.95      4830
#            6       0.97      0.92      0.95      3171
#
#     accuracy                           0.96     28709
#    macro avg       0.95      0.92      0.94     28709
# weighted avg       0.96      0.96      0.96     28709

# %%
test_labels_encoded = label_encoder.fit_transform(test_labels)

# %%
transformed_features_test
