# %% [markdown]
# # LSTM

# %%
# Check the current working directory
import os
print("Current working directory:", os.getcwd())
# Out:
# Current working directory: /Users/ching-lung/deposit-prediction

# %% [markdown]
# ### Import packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
from datetime import datetime
from statsmodels.tsa.stattools import adfuller
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout
import statsmodels
import statsmodels.api as sm
from statsmodels.graphics import tsaplots

# %% [markdown]
# ### Import Dataset

# %%
# Load the .dta file into a DataFrame
df = pd.read_csv("/Users/ching-lung/deposit-prediction/LSTM/daily-treasury-rates_data.csv")
df.head(5)
# Out:
#        Date  1 Mo  2 Mo  3 Mo  4 Mo  6 Mo  1 Yr  2 Yr  3 Yr  5 Yr  7 Yr  \
# 0  9/8/2023  5.52  5.56  5.55  5.60  5.49  5.42  4.98  4.68  4.39  4.35
# 1  9/7/2023  5.52  5.56  5.53  5.59  5.50  5.40  4.94  4.66  4.38  4.35
# 2  9/6/2023  5.52  5.55  5.55  5.60  5.52  5.44  5.01  4.73  4.44  4.39
# 3  9/5/2023  5.51  5.56  5.55  5.59  5.51  5.42  4.94  4.65  4.37  4.35
# 4  9/1/2023  5.51  5.55  5.53  5.58  5.47  5.36  4.87  4.57  4.29  4.27
#
#    10 Yr  20 Yr  30 Yr
# 0   4.26   4.52   4.33
# 1   4.27   4.55   4.36
# 2   4.30   4.56   4.37
# 3   4.27   4.56   4.38
# 4   4.18   4.48   4.29

# %%
#define a function to preprocess the x and y variables
def prepare_data(timeseries_data, n_steps):
    x, y = [], []
    for i in range(len(timeseries_data)):
        end_ix = i + n_steps  # find the end of this pattern
        if end_ix > len(timeseries_data) - 1:  # if longer than timeseries, break the loop
            break
        # gather the input and output sequences
        seq_x = timeseries_data[i:end_ix]
        seq_y = timeseries_data[end_ix]
        x.append(seq_x)
        y.append(seq_y)
    return np.array(x), np.array(y)

n_steps = 60
n_features = 1

x, y = prepare_data(np.array(df[['1 Mo']]), n_steps)
x.shape, y.shape
# Out:
# ((2864, 60, 1), (2864, 1))

# %%
# initiate the model
model = Sequential()  # initiate the model
# Add input layer with 50 neurons
model.add(LSTM(50, activation='relu', return_sequences=True, input_shape=(n_steps, n_features)))
# Add second layer with 50 neurons
model.add(LSTM(50, activation='relu'))
# Add a fully connected output layer with 1 output
model.add(Dense(1))
# compile the model
model.compile(optimizer='adam', loss='mse')

# fit the model
model.fit(x, y, epochs=50, verbose=1)

yhat = model.predict(x[185::], verbose=0)
yhat
# Out:
# Epoch 1/50
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 1.1305
# Epoch 2/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.4322
# Epoch 3/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0834
# Epoch 4/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0541
# Epoch 5/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0635
# Epoch 6/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0408
# Epoch 7/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0169
# Epoch 8/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0284
# Epoch 9/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 0.0234
# Epoch 10/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0210
# Epoch 11/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0226
# Epoch 12/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0154
# Epoch 13/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0193
# Epoch 14/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0505
# Epoch 15/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0180
# Epoch 16/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0336
# Epoch 17/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0175
# Epoch 18/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0106
# Epoch 19/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0223
# Epoch 20/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0077
# Epoch 21/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0189
# Epoch 22/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0130
# Epoch 23/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0226
# Epoch 24/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0256
# Epoch 25/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0178
# Epoch 26/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0057
# Epoch 27/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0146
# Epoch 28/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0246
# Epoch 29/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0247
# Epoch 30/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0221
# Epoch 31/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0170
# Epoch 32/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0188
# Epoch 33/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0149
# Epoch 34/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0070
# Epoch 35/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0101
# Epoch 36/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0397
# Epoch 37/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0092
# Epoch 38/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0085
# Epoch 39/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0122
# Epoch 40/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0107
# Epoch 41/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0095
# Epoch 42/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0143
# Epoch 43/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0212
# Epoch 44/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0102
# Epoch 45/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0069
# Epoch 46/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0125
# Epoch 47/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0167
# Epoch 48/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0142
# Epoch 49/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0100
# Epoch 50/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0082
# array([[0.11079921],
#        [0.12270348],
#        [0.12497364],
#        ...,
#        [0.11550707],
#        [0.11611713],
#        [0.11227106]], dtype=float32)
