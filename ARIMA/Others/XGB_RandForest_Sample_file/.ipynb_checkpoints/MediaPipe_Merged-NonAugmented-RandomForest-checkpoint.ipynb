# %% [markdown]
# Download FER-2013 from Kaggle

# %%
pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (1.6.17)
# Requirement already satisfied: six>=1.10 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from kaggle) (1.16.0)
# Requirement already satisfied: certifi>=2023.7.22 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from kaggle) (2024.8.30)
# Requirement already satisfied: python-dateutil in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: requests in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from kaggle) (2.32.3)
# Requirement already satisfied: tqdm in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from kaggle) (4.66.5)
# Requirement already satisfied: python-slugify in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from kaggle) (5.0.2)
# Requirement already satisfied: urllib3 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from kaggle) (2.2.3)
# Requirement already satisfied: bleach in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from kaggle) (4.1.0)
# Requirement already satisfied: packaging in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from bleach->kaggle) (24.1)
# Requirement already satisfied: webencodings in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from requests->kaggle) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from requests->kaggle) (3.7)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
# Specify the directory to save the dataset
save_directory_data = os.path.expanduser('~/Downloads')
os.makedirs(save_directory_data, exist_ok=True)
# Download the dataset
os.system(f'kaggle datasets download -d msambare/fer2013 -p "{save_directory_data}"')
# Out:
# Dataset URL: https://www.kaggle.com/datasets/msambare/fer2013
# License(s): DbCL-1.0
# fer2013.zip: Skipping, found more recently modified local copy (use --force to force download)
# 0

# %%
import cv2
import matplotlib.pyplot as plt
import random
from collections import Counter
import numpy as np
import pandas as pd
import random
from torchvision import transforms
from PIL import Image
from sklearn.model_selection import train_test_split
import shutil
from sklearn.preprocessing import LabelEncoder
from skimage import exposure
import os
import matplotlib.pyplot as plt
import mediapipe as mp
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf
from sklearn.model_selection import KFold, cross_val_score
from sklearn.svm import SVC

# %%
# Directory paths
train_dir = os.path.expanduser('/Users/sherrywang/Desktop/fer2013/train')
test_dir = os.path.expanduser('/Users/sherrywang/Desktop/fer2013/test')

# %%
# Define a function to load data
def load_images_from_directory(directory):
    images = []
    labels = []
    for label in os.listdir(directory):
        label_path = os.path.join(directory, label)
        if os.path.isdir(label_path):
            for file in os.listdir(label_path):
                file_path = os.path.join(label_path, file)
                image = cv2.imread(file_path, cv2.IMREAD_GRAYSCALE)
                images.append(image)
                labels.append(label)
    return images, labels

# Load training and testing images
train_images, train_labels = load_images_from_directory(train_dir)
test_images, test_labels = load_images_from_directory(test_dir)

print(f"Loaded {len(train_images)} training images and {len(test_images)} testing images.")
# Out:
# Loaded 28709 training images and 7178 testing images.

# %%
# Define a function to count the number of images in each category
def count_images_per_category(labels, dataset_label):
    category_counts = Counter(labels)
    total_images = len(labels)
    
    # Print the counts for each category
    print(f"\n{dataset_label} set:")
    for category, count in category_counts.items():
        print(f"Category '{category}': {count} images")
    
    print(f"Total number of images in {dataset_label} set: {total_images}")
    return category_counts, total_images

# Count images in training and testing
train_counts, num_train_images = count_images_per_category(train_labels, "Training")
test_counts, num_test_images = count_images_per_category(test_labels, "Testing")
# Out:
# Training set:
# Category 'happy': 7215 images
# Category 'sad': 4830 images
# Category 'fear': 4097 images
# Category 'surprise': 3171 images
# Category 'neutral': 4965 images
# Category 'angry': 3995 images
# Category 'disgust': 436 images
# Total number of images in Training set: 28709
#
# Testing set:
# Category 'happy': 1774 images
# Category 'sad': 1247 images
# Category 'fear': 1024 images
# Category 'surprise': 831 images
# Category 'neutral': 1233 images
# Category 'angry': 958 images
# Category 'disgust': 111 images
# Total number of images in Testing set: 7178

# %% [markdown]
# Visualzie Random Samples from Each Category

# %%
# Define a function to visualize random samples from each category
def visualize_samples(images, labels, num_samples=5, dataset_label="Dataset"):
    unique_labels = set(labels)
    
    for label in unique_labels:
        label_images = [img for img, lbl in zip(images, labels) if lbl == label]
        
        print(f"Label: {label}")
        sample_images = random.sample(label_images, min(num_samples, len(label_images)))
        
        plt.figure(figsize=(15, 3))
        for i, image in enumerate(sample_images):
            plt.subplot(1, num_samples, i + 1)
            plt.imshow(image, cmap='gray')
            plt.title(label)
            plt.axis('off')
        
        plt.show()

# Visualize samples from training and testing
visualize_samples(train_images, train_labels, num_samples=5, dataset_label="Training")
visualize_samples(test_images, test_labels, num_samples=5, dataset_label="Testing")
# Out:
# Label: happy
# Label: sad
# Label: disgust
# Label: surprise
# Label: fear
# Label: angry
# Label: neutral
# Label: happy
# Label: sad
# Label: disgust
# Label: surprise
# Label: fear
# Label: angry
# Label: neutral

# %% [markdown]
# Data Cleaning

# %%
# Define a function to check if images are loaded correctly and correct size
def check_images(images, labels, dataset_label="Dataset"):
    invalid_images = []
    for i, image in enumerate(images):
        if image is None or image.shape != (48, 48):
            print(f"Invalid image detected in {dataset_label} set: Label - {labels[i]}, Index - {i}")
            invalid_images.append((labels[i], i))  # Store label and index of invalid images
    print(f"Total invalid images in {dataset_label} set: {len(invalid_images)}")

# Check the training and testing sets in memory
check_images(train_images, train_labels, dataset_label="Training")
check_images(test_images, test_labels, dataset_label="Testing")
# Out:
# Total invalid images in Training set: 0
# Total invalid images in Testing set: 0

# %% [markdown]
# Addressing Data Imbalance: Step 1 Downsample 'happy' to 5000 Images

# %% [markdown]
# Addressing Data Imbalance: Step 2 Augmentation

# %% [markdown]
# Count the Number of Images in Each Category

# %%
# Load training balanced dataset
train_images, train_labels = load_images_from_directory(train_dir)
test_images, test_labels = load_images_from_directory(test_dir)
# Count images in training balanced dataset
train_counts, num_train_images = count_images_per_category(train_labels, "Training")
# Out:
# Training set:
# Category 'happy': 7215 images
# Category 'sad': 4830 images
# Category 'fear': 4097 images
# Category 'surprise': 3171 images
# Category 'neutral': 4965 images
# Category 'angry': 3995 images
# Category 'disgust': 436 images
# Total number of images in Training set: 28709

# %% [markdown]
# Feature Extraction for Training Balanced Dataset

# %%
mp_face_mesh = mp.solutions.face_mesh
face_mesh = mp_face_mesh.FaceMesh(static_image_mode=True, max_num_faces=1, refine_landmarks=True)  


def extract_mediapipe_features(image, label_images):
 
    """
    Extract facial landmarks using MediaPipe Face Mesh. If no face is detected,
    continually retry with a randomly selected and augmented image from the same label.
    
    Parameters:
    - image: The initial input image to extract features from.
    - label_images: List of images under the same label to select from if retry is needed.
    
    Returns:
    - feature_vector: List of landmark (x, y, z) coordinates.
    """

    while True:
        # Ensure image is of type uint8 (0-255 range)
        image_uint8 = np.array(image, dtype=np.uint8)
        
        # Convert to RGB if grayscale
        if len(image_uint8.shape) == 2:  # Grayscale image
            image_rgb = cv2.cvtColor(image_uint8, cv2.COLOR_GRAY2RGB)
        else:
            image_rgb = image_uint8
        
        # Verify and re-cast to ensure MediaPipe compatibility
        image_rgb = np.array(image_rgb, dtype=np.uint8)
        #print("Image shape after conversion:", image_rgb.shape, "Data type:", image_rgb.dtype)
        
        # Process with MediaPipe Face Mesh
        results = face_mesh.process(image_rgb)
        
        if results.multi_face_landmarks:
            # Extract landmark coordinates for the detected face
            feature_vector = []
            for landmark in results.multi_face_landmarks[0].landmark:
                x, y, z = landmark.x, landmark.y, landmark.z
                #flattened 1d features
                feature_vector.extend([x, y, z]) 
                #feature_vector.append([x, y, z])
            return feature_vector  # Return feature vector if landmarks are detected
        
        # If no face is detected, print message and retry with augmented image
        print("No face detected in the image. Retrying with augmented image...")
        image = random.choice(label_images)  # Randomly choose a new image from the same label


# Process each category separately
train_features = []
test_features = []
for label in set(train_labels):  # Iterate over each unique label
    # Filter images and labels for the current label
    label_images = [img for img, lbl in zip(train_images, train_labels) if lbl == label]
    
    # Process each image in the current label category
    for i, image in enumerate(label_images):
        #print(f"Processing image {i+1}/{len(label_images)} for label '{label}'")
        feature_vector = extract_mediapipe_features(image, label_images)  # Pass both image and label_images
        if feature_vector is not None:
            train_features.append(feature_vector)

print("Feature extraction completed.")

for label in set(test_labels):  # Iterate over each unique label
    # Filter images and labels for the current label
    label_images = [img for img, lbl in zip(test_images, test_labels) if lbl == label]
    
    # Process each image in the current label category
    for i, image in enumerate(label_images):
        #print(f"Processing image {i+1}/{len(label_images)} for label '{label}'")
        feature_vector = extract_mediapipe_features(image, label_images)  # Pass both image and label_images
        if feature_vector is not None:
            test_features.append(feature_vector)

print("Feature extraction completed.")


# Encode labels
label_encoder = LabelEncoder()
train_labels_encoded = label_encoder.fit_transform(train_labels)

# Specify the directory to save extracted features and encoded labels
save_directory_features = os.path.expanduser('~/Downloads/fer2013/ExtractedFeatures_media')
os.makedirs(save_directory_features, exist_ok=True)

# Save MediaPipe features and encoded labels
np.save(f'{save_directory_features}/train_Media.npy', train_features)
np.save(f'{save_directory_features}/train_labels_encoded_Media.npy', train_labels_encoded)
print("Features and labels saved successfully.")
# Out:
# No face detected in the image. Retrying with augmented image...
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1732579972.727409 7204269 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88.1), renderer: Apple M3
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# W0000 00:00:1732579972.735266 7204573 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1732579972.739139 7204573 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1732579972.741158 7204572 landmark_projection_calculator.cc:186] Using NORM_RECT without IMAGE_DIMENSIONS is only supported for the square ROI. Provide IMAGE_DIMENSIONS or use PROJECTION_MATRIX.
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# ...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# Feature extraction completed.
# Features and labels saved successfully.

# %%
    """# Load HOG features and encoded labels
train_features = np.load(f'{save_directory_features}/train_Media.npy')
train_labels_encoded = np.load(f'{save_directory_features}/train_labels_encoded_Media.npy')
print("Features and labels loaded successfully.")

# Print the shape of train_features
print("Shape of train MediaPipe features:", train_features.shape)
    """
# Out:
# '# Load HOG features and encoded labels\ntrain_features = np.load(f\'{save_directory_features}/train_Media.npy\')\ntrain_labels_encoded = np.load(f\'{save_directory_features}/train_labels_encoded_Media.npy\')\nprint("Features and labels loaded successfully.")\n\n# Print the shape of train_features\nprint("Shape of train MediaPipe features:", train_features.shape)\n'

# %%
# Load training balanced dataset
test_images, test_labels = load_images_from_directory(test_dir)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV, cross_val_predict, cross_val_score, KFold, StratifiedKFold, train_test_split
from sklearn.metrics import classification_report

# %%
# Standardize the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(train_features)

# Apply PCA to reduce dimensionality
pca = PCA(n_components=15)
X_train_pca = pca.fit_transform(X_train_scaled)

# Check the amount of variance explained by the components
explained_variance = np.sum(pca.explained_variance_ratio_)
print(f"Explained variance with {pca.n_components_} components: {explained_variance:.2f}")
# Out:
# Explained variance with 15 components: 1.00

# %%
import numpy as np
import pandas as pd
import os
import cv2
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler

# %%
test_scaled_features = scaler.fit_transform(test_features)

# Apply PCA
transformed_features_test = pca.fit_transform(test_scaled_features)

# %%
def auto_random_forest(
    X,
    y,
    n_estimators=100,
    cv=10,
    random_state=2024
):
    """
    Implement Random Forest with different max_features settings and find optimal value
    
    Parameters:
    X, y: pandas DataFrame containing features and target
    test_size: proportion of data to use for testing in CV
    random_state: random state for reproducibility
    n_estimators: number of trees in forest
    cv: number of cross-validation folds
    """
    
    # number of features
    n_features = np.array(X).shape[1]
    
    # Create different max_features values to try
    # Include common options and some specific numbers
    max_features_options = [
        "log2",
        "sqrt",
        0.1,     # 10% of features
        0.2,     # 20% of features
    ]
    
    # Scale features
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)
    
    # Create parameter grid
    param_grid = {
        'max_features': max_features_options,
        'min_samples_split': [2, 5, 10, 20, 30, 40, 50],
        # 'min_samples_leaf': [2, 5, 10, 20, 30, 40, 50]
        'max_depth': [3, 5, 7, 10, 20, 30]
    }
    
    # Initialize Random Forest
    rf = RandomForestClassifier(
        n_estimators=n_estimators,
        random_state=random_state
    )
    
    # 3. Setup StratifiedKFold
    skf = StratifiedKFold(
        n_splits=cv,
        shuffle=True,
        random_state=random_state
    )
    
    # Perform grid search
    grid_search = GridSearchCV(
        estimator=rf,
        param_grid=param_grid,
        cv=skf,
        scoring='accuracy',
        n_jobs=-1, # use all the CPU cores
        verbose=2  # detailed output monitoring progress updates
    )
    
    # Fit grid search
    grid_search.fit(X_scaled, y)
    
    # Get best model, best params, and best score
    best_rf = grid_search.best_estimator_
    best_par = grid_search.best_params_
    best_score = grid_search.best_score_
    
    # Compile results
    results = {
        'best_params': best_par,
        'best_score': best_score,
        'best_model': best_rf
    }
    
    return results

# %%
# Grid search the best model
random_forest_result = auto_random_forest(X=X_train_pca, y=train_labels_encoded)
# Out:
# Fitting 10 folds for each of 168 candidates, totalling 1680 fits
# [CV] END max_depth=3, max_features=log2, min_samples_split=2; total time=   2.0s
# [CV] END max_depth=3, max_features=log2, min_samples_split=5; total time=   2.1s
# [CV] END max_depth=3, max_features=log2, min_samples_split=10; total time=   2.1s
# [CV] END max_depth=3, max_features=log2, min_samples_split=20; total time=   2.1s
# [CV] END max_depth=3, max_features=log2, min_samples_split=20; total time=   2.1s
# [CV] END max_depth=3, max_features=log2, min_samples_split=30; total time=   2.1s
# [CV] END max_depth=3, max_features=log2, min_samples_split=40; total time=   2.0s
# [CV] END max_depth=3, max_features=log2, min_samples_split=50; total time=   2.0s
# [CV] END max_depth=3, max_features=sqrt, min_samples_split=2; total time=   2.1s
# [CV] END max_depth=3, max_features=sqrt, min_samples_split=2; total time=   2.1s
# [CV] END max_depth=3, max_features=sqrt, min_samples_split=5; total time=   2.0s
# [CV] END max_depth=3, max_features=sqrt, min_samples_split=10; total time=   2.0s
# [CV] END max_depth=3, max_features=sqrt, min_samples_split=20; total time=   2.1s
# [CV] END max_depth=3, max_features=sqrt, min_samples_split=30; total time=   2.2s
# [CV] END max_depth=3, max_features=sqrt, min_samples_split=30; total time=   2.2s
# [CV] END max_depth=3, max_features=sqrt, min_samples_split=40; total time=   2.2s
# [CV] END max_depth=3, max_features=sqrt, min_samples_split=50; total time=   2.1s
# [CV] END .max_depth=3, max_features=0.1, min_samples_split=2; total time=   0.9s
# [CV] END .max_depth=3, max_features=0.1, min_samples_split=2; total time=   0.9s
# [CV] END .max_depth=3, max_features=0.1, min_samples_split=5; total time=   0.9s
# [CV] END max_depth=3, max_features=0.1, min_samples_split=10; total time=   0.9s
# [CV] END max_depth=3, max_features=0.1, min_samples_split=20; total time=   0.8s
# [CV] END max_depth=3, max_features=0.1, min_samples_split=20; total time=   0.8s
# [CV] END max_depth=3, max_features=0.1, min_samples_split=30; total time=   1.0s
# [CV] END max_depth=3, max_features=0.1, min_samples_split=40; total time=   0.8s
# [CV] END max_depth=3, max_features=0.1, min_samples_split=50; total time=   0.9s
# [CV] END .max_depth=3, max_features=0.2, min_samples_split=2; total time=   2.1s
# [CV] END .max_depth=3, max_features=0.2, min_samples_split=2; total time=   2.0s
# [CV] END .max_depth=3, max_features=0.2, min_samples_split=5; total time=   2.0s
# [CV] END max_depth=3, max_features=0.2, min_samples_split=10; total time=   2.0s
# [CV] END max_depth=3, max_features=0.2, min_samples_split=20; total time=   2.1s
# [CV] END max_depth=3, max_features=0.2, min_samples_split=30; total time=   2.1s
# [CV] END max_depth=3, max_features=0.2, min_samples_split=30; total time=   2.1s
# [CV] END max_depth=3, max_features=0.2, min_samples_split=40; total time=   2.0s
# [CV] END max_depth=3, max_features=0.2, min_samples_split=50; total time=   2.0s
# [CV] END max_depth=5, max_features=log2, min_samples_split=2; total time=   3.3s
# [CV] END max_depth=5, max_features=log2, min_samples_split=5; total time=   3.3s
# [CV] END max_depth=5, max_features=log2, min_samples_split=5; total time=   3.0s
# [CV] END max_depth=5, max_features=log2, min_samples_split=10; total time=   3.2s
# [CV] END max_depth=5, max_features=log2, min_samples_split=20; total time=   3.1s
# [CV] END max_depth=5, max_features=log2, min_samples_split=30; total time=   3.3s
# [CV] END max_depth=5, max_features=log2, min_samples_split=40; total time=   3.3s
# [CV] END max_depth=5, max_features=log2, min_samples_split=40; total time=   3.1s
# [CV] END max_depth=5, max_features=log2, min_samples_split=50; total time=   3.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_split=2; total time=   3.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_split=5; total time=   3.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_split=10; total time=   3.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_split=10; total time=   3.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_split=20; total time=   3.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_split=30; total time=   3.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_split=40; total time=   3.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_split=50; total time=   3.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_split=50; total time=   3.1s
# [CV] END .max_depth=5, max_features=0.1, min_samples_split=5; total time=   1.2s
# [CV] END max_depth=5, max_features=0.1, min_samples_split=10; total time=   1.2s
# [CV] END max_depth=5, max_features=0.1, min_samples_split=20; total time=   1.2s
# [CV] END max_depth=5, max_features=0.1, min_samples_split=30; total time=   1.2s
# [CV] END max_depth=5, max_features=0.1, min_samples_split=30; total time=   1.2s
# [CV] END max_depth=5, max_features=0.1, min_samples_split=40; total time=   1.3s
# [CV] END max_depth=5, max_features=0.1, min_samples_split=50; total time=   1.2s
# [CV] END .max_depth=5, max_features=0.2, min_samples_split=2; total time=   3.2s
# [CV] END .max_depth=5, max_features=0.2, min_samples_split=5; total time=   3.0s
# [CV] END .max_depth=5, max_features=0.2, min_samples_split=5; total time=   3.1s
# [CV] END max_depth=5, max_features=0.2, min_samples_split=10; total time=   3.2s
# [CV] END max_depth=5, max_features=0.2, min_samples_split=20; total time=   3.1s
# [CV] END max_depth=5, max_features=0.2, min_samples_split=30; total time=   3.1s
# [CV] END max_depth=5, max_features=0.2, min_samples_split=40; total time=   3.1s
# [CV] END max_depth=5, max_features=0.2, min_samples_split=40; total time=   3.1s
# [CV] END max_depth=5, max_features=0.2, min_samples_split=50; total time=   3.1s
# [CV] END max_depth=7, max_features=log2, min_samples_split=2; total time=   4.1s
# [CV] END max_depth=7, max_features=log2, min_samples_split=5; total time=   4.1s
# [CV] END max_depth=7, max_features=log2, min_samples_split=10; total time=   4.0s
# [CV] END max_depth=7, max_features=log2, min_samples_split=10; total time=   4.1s
# [CV] END max_depth=7, max_features=log2, min_samples_split=20; total time=   4.0s
# [CV] END max_depth=7, max_features=log2, min_samples_split=30; total time=   4.1s
# [CV] END max_depth=7, max_features=log2, min_samples_split=40; total time=   4.1s
# [CV] END max_depth=7, max_features=log2, min_samples_split=50; total time=   4.1s
# [CV] END max_depth=7, max_features=log2, min_samples_split=50; total time=   4.1s
# [CV] END max_depth=7, max_features=sqrt, min_samples_split=2; total time=   4.0s
# [CV] END max_depth=7, max_features=sqrt, min_samples_split=5; total time=   4.3s
# [CV] END max_depth=7, max_features=sqrt, min_samples_split=10; total time=   4.1s
# [CV] END max_depth=7, max_features=sqrt, min_samples_split=20; total time=   4.0s
# [CV] END max_depth=7, max_features=sqrt, min_samples_split=20; total time=   4.1s
# [CV] END max_depth=7, max_features=sqrt, min_samples_split=30; total time=   4.1s
# [CV] END max_depth=7, max_features=sqrt, min_samples_split=40; total time=   4.0s
# [CV] END max_depth=7, max_features=sqrt, min_samples_split=50; total time=   4.0s
# [CV] END .max_depth=7, max_features=0.1, min_samples_split=2; total time=   1.6s
# [CV] END .max_depth=7, max_features=0.1, min_samples_split=2; total time=   1.6s
# [CV] END .max_depth=7, max_features=0.1, min_samples_split=5; total time=   1.6s
# [CV] END max_depth=7, max_features=0.1, min_samples_split=10; total time=   1.6s
# [CV] END max_depth=7, max_features=0.1, min_samples_split=10; total time=   1.6s
# [CV] END max_depth=7, max_features=0.1, min_samples_split=20; total time=   1.6s
# [CV] END max_depth=7, max_features=0.1, min_samples_split=30; total time=   1.6s
# [CV] END max_depth=7, max_features=0.1, min_samples_split=40; total time=   1.6s
# [CV] END max_depth=7, max_features=0.1, min_samples_split=50; total time=   1.6s
# [CV] END .max_depth=7, max_features=0.2, min_samples_split=2; total time=   4.1s
# [CV] END .max_depth=7, max_features=0.2, min_samples_split=2; total time=   4.0s
# [CV] END .max_depth=7, max_features=0.2, min_samples_split=5; total time=   4.1s
# [CV] END max_depth=7, max_features=0.2, min_samples_split=10; total time=   4.1s
# [CV] END max_depth=7, max_features=0.2, min_samples_split=20; total time=   4.1s
# [CV] END max_depth=7, max_features=0.2, min_samples_split=30; total time=   4.0s
# [CV] END max_depth=7, max_features=0.2, min_samples_split=30; total time=   4.0s
# [CV] END max_depth=7, max_features=0.2, min_samples_split=40; total time=   4.1s
# [CV] END max_depth=7, max_features=0.2, min_samples_split=50; total time=   4.1s
# [CV] END max_depth=10, max_features=log2, min_samples_split=2; total time=   5.4s
# [CV] END max_depth=10, max_features=log2, min_samples_split=5; total time=   5.3s
# [CV] END max_depth=10, max_features=log2, min_samples_split=5; total time=   5.4s
# [CV] END max_depth=10, max_features=log2, min_samples_split=10; total time=   5.4s
# [CV] END max_depth=10, max_features=log2, min_samples_split=20; total time=   5.3s
# [CV] END max_depth=10, max_features=log2, min_samples_split=30; total time=   5.3s
# [CV] END max_depth=10, max_features=log2, min_samples_split=40; total time=   5.2s
# [CV] END max_depth=10, max_features=log2, min_samples_split=40; total time=   5.3s
# [CV] END max_depth=10, max_features=log2, min_samples_split=50; total time=   5.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=2; total time=   5.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=5; total time=   5.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=10; total time=   5.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=10; total time=   5.4s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=20; total time=   5.7s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=30; total time=   5.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=40; total time=   5.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=50; total time=   5.3s
# [CV] END max_depth=10, max_features=0.1, min_samples_split=2; total time=   2.1s
# [CV] END max_depth=10, max_features=0.1, min_samples_split=2; total time=   2.1s
# [CV] END max_depth=10, max_features=0.1, min_samples_split=5; total time=   2.1s
# [CV] END max_depth=10, max_features=0.1, min_samples_split=5; total time=   2.1s
# [CV] END max_depth=10, max_features=0.1, min_samples_split=10; total time=   2.1s
# [CV] END max_depth=10, max_features=0.1, min_samples_split=20; total time=   2.0s
# [CV] END max_depth=10, max_features=0.1, min_samples_split=30; total time=   2.0s
# [CV] END max_depth=10, max_features=0.1, min_samples_split=40; total time=   2.1s
# [CV] END max_depth=10, max_features=0.1, min_samples_split=40; total time=   2.0s
# [CV] END max_depth=10, max_features=0.1, min_samples_split=50; total time=   2.1s
# [CV] END max_depth=10, max_features=0.2, min_samples_split=2; total time=   5.3s
# [CV] END max_depth=10, max_features=0.2, min_samples_split=5; total time=   5.4s
# [CV] END max_depth=10, max_features=0.2, min_samples_split=10; total time=   5.4s
# [CV] END max_depth=10, max_features=0.2, min_samples_split=10; total time=   5.3s
# [CV] END max_depth=10, max_features=0.2, min_samples_split=20; total time=   5.3s
# [CV] END max_depth=10, max_features=0.2, min_samples_split=30; total time=   5.3s
# [CV] END max_depth=10, max_features=0.2, min_samples_split=40; total time=   5.3s
# [CV] END max_depth=10, max_features=0.2, min_samples_split=50; total time=   5.2s
# [CV] END max_depth=10, max_features=0.2, min_samples_split=50; total time=   5.2s
# [CV] END max_depth=20, max_features=log2, min_samples_split=2; total time=   7.7s
# [CV] END max_depth=20, max_features=log2, min_samples_split=5; total time=   7.7s
# [CV] END max_depth=20, max_features=log2, min_samples_split=10; total time=   7.5s
# [CV] END max_depth=20, max_features=log2, min_samples_split=20; total time=   7.1s
# [CV] END max_depth=20, max_features=log2, min_samples_split=20; total time=   7.2s
# [CV] END max_depth=20, max_features=log2, min_samples_split=30; total time=   6.9s
# [CV] END max_depth=20, max_features=log2, min_samples_split=40; total time=   6.7s
# [CV] END max_depth=20, max_features=log2, min_samples_split=50; total time=   6.6s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=2; total time=   7.8s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=2; total time=   7.8s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=5; total time=   7.8s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=10; total time=   7.5s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=20; total time=   7.1s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=30; total time=   6.9s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=30; total time=   6.8s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=40; total time=   6.6s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=50; total time=   6.5s
# [CV] END max_depth=20, max_features=0.1, min_samples_split=2; total time=   3.2s
# [CV] END max_depth=20, max_features=0.1, min_samples_split=2; total time=   3.2s
# [CV] END max_depth=20, max_features=0.1, min_samples_split=5; total time=   3.1s
# [CV] END max_depth=20, max_features=0.1, min_samples_split=10; total time=   3.0s
# [CV] END max_depth=20, max_features=0.1, min_samples_split=20; total time=   2.9s
# [CV] END max_depth=20, max_features=0.1, min_samples_split=30; total time=   2.8s
# [CV] END max_depth=20, max_features=0.1, min_samples_split=30; total time=   2.8s
# [CV] END max_depth=20, max_features=0.1, min_samples_split=40; total time=   2.7s
# [CV] END max_depth=20, max_features=0.1, min_samples_split=50; total time=   2.6s
# [CV] END max_depth=20, max_features=0.2, min_samples_split=2; total time=   7.9s
# [CV] END max_depth=20, max_features=0.2, min_samples_split=5; total time=   7.8s
# [CV] END max_depth=20, max_features=0.2, min_samples_split=5; total time=   7.7s
# [CV] END max_depth=20, max_features=0.2, min_samples_split=10; total time=   7.4s
# [CV] END max_depth=20, max_features=0.2, min_samples_split=20; total time=   7.1s
# [CV] END max_depth=20, max_features=0.2, min_samples_split=30; total time=   6.7s
# [CV] END max_depth=20, max_features=0.2, min_samples_split=40; total time=   6.6s
# [CV] END max_depth=20, max_features=0.2, min_samples_split=40; total time=   6.8s
# [CV] END max_depth=20, max_features=0.2, min_samples_split=50; total time=   6.5s
# [CV] END max_depth=30, max_features=log2, min_samples_split=2; total time=   8.0s
# [CV] END max_depth=30, max_features=log2, min_samples_split=5; total time=   7.7s
# [CV] END max_depth=30, max_features=log2, min_samples_split=10; total time=   7.5s
# [CV] END max_depth=30, max_features=log2, min_samples_split=10; total time=   7.6s
# [CV] END max_depth=30, max_features=log2, min_samples_split=20; total time=   7.2s
# [CV] END max_depth=30, max_features=log2, min_samples_split=30; total time=   6.9s
# [CV] END max_depth=30, max_features=log2, min_samples_split=40; total time=   6.7s
# [CV] END max_depth=30, max_features=log2, min_samples_split=50; total time=   6.5s
# [CV] END max_depth=30, max_features=log2, min_samples_split=50; total time=   6.6s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=2; total time=   8.0s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=5; total time=   7.8s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=10; total time=   7.6s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=20; total time=   7.2s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=20; total time=   7.2s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=30; total time=   6.9s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=40; total time=   6.6s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=50; total time=   6.6s
# [CV] END max_depth=30, max_features=0.1, min_samples_split=2; total time=   3.4s
# /Users/sherrywang/anaconda3/lib/python3.12/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [CV] END max_depth=3, max_features=log2, min_samples_split=2; total time=   2.1s
# [CV] END max_depth=3, max_features=log2, min_samples_split=5; total time=   2.1s
# [CV] END max_depth=3, max_features=log2, min_samples_split=5; total time=   2.0s
# [CV] END max_depth=3, max_features=log2, min_samples_split=10; total time=   2.1s
# [CV] END max_depth=3, max_features=log2, min_samples_split=20; total time=   2.0s
# [CV] END max_depth=3, max_features=log2, min_samples_split=30; total time=   2.1s
# [CV] END max_depth=3, max_features=log2, min_samples_split=40; total time=   2.0s
# [CV] END max_depth=3, max_features=log2, min_samples_split=50; total time=   2.0s
# [CV] END max_depth=3, max_features=log2, min_samples_split=50; total time=   2.1s
# [CV] END max_depth=3, max_features=sqrt, min_samples_split=2; total time=   2.1s
# [CV] END max_depth=3, max_features=sqrt, min_samples_split=5; total time=   2.0s
# [CV] END max_depth=3, max_features=sqrt, min_samples_split=10; total time=   2.0s
# [CV] END max_depth=3, max_features=sqrt, min_samples_split=20; total time=   2.0s
# [CV] END max_depth=3, max_features=sqrt, min_samples_split=20; total time=   2.1s
# [CV] END max_depth=3, max_features=sqrt, min_samples_split=30; total time=   2.2s
# [CV] END max_depth=3, max_features=sqrt, min_samples_split=40; total time=   2.1s
# [CV] END max_depth=3, max_features=sqrt, min_samples_split=50; total time=   2.1s
# [CV] END max_depth=3, max_features=sqrt, min_samples_split=50; total time=   2.0s
# [CV] END .max_depth=3, max_features=0.1, min_samples_split=5; total time=   0.9s
# [CV] END max_depth=3, max_features=0.1, min_samples_split=10; total time=   0.8s
# [CV] END max_depth=3, max_features=0.1, min_samples_split=10; total time=   0.9s
# [CV] END max_depth=3, max_features=0.1, min_samples_split=20; total time=   0.8s
# [CV] END max_depth=3, max_features=0.1, min_samples_split=30; total time=   0.8s
# [CV] END max_depth=3, max_features=0.1, min_samples_split=40; total time=   0.8s
# [CV] END max_depth=3, max_features=0.1, min_samples_split=50; total time=   0.9s
# [CV] END max_depth=3, max_features=0.1, min_samples_split=50; total time=   0.9s
# [CV] END .max_depth=3, max_features=0.2, min_samples_split=2; total time=   2.1s
# [CV] END .max_depth=3, max_features=0.2, min_samples_split=5; total time=   2.1s
# [CV] END max_depth=3, max_features=0.2, min_samples_split=10; total time=   2.0s
# [CV] END max_depth=3, max_features=0.2, min_samples_split=20; total time=   2.0s
# [CV] END max_depth=3, max_features=0.2, min_samples_split=20; total time=   2.0s
# [CV] END max_depth=3, max_features=0.2, min_samples_split=30; total time=   2.2s
# [CV] END max_depth=3, max_features=0.2, min_samples_split=40; total time=   2.1s
# [CV] END max_depth=3, max_features=0.2, min_samples_split=50; total time=   2.0s
# [CV] END max_depth=5, max_features=log2, min_samples_split=2; total time=   3.4s
# [CV] END max_depth=5, max_features=log2, min_samples_split=2; total time=   3.3s
# [CV] END max_depth=5, max_features=log2, min_samples_split=5; total time=   3.1s
# [CV] END max_depth=5, max_features=log2, min_samples_split=10; total time=   3.1s
# [CV] END max_depth=5, max_features=log2, min_samples_split=20; total time=   3.2s
# [CV] END max_depth=5, max_features=log2, min_samples_split=30; total time=   3.3s
# [CV] END max_depth=5, max_features=log2, min_samples_split=30; total time=   3.3s
# [CV] END max_depth=5, max_features=log2, min_samples_split=40; total time=   3.1s
# [CV] END max_depth=5, max_features=log2, min_samples_split=50; total time=   3.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_split=2; total time=   3.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_split=5; total time=   3.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_split=5; total time=   3.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_split=10; total time=   3.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_split=20; total time=   3.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_split=30; total time=   3.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_split=40; total time=   3.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_split=40; total time=   3.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_split=50; total time=   3.1s
# [CV] END .max_depth=5, max_features=0.1, min_samples_split=2; total time=   1.3s
# [CV] END .max_depth=5, max_features=0.1, min_samples_split=5; total time=   1.2s
# [CV] END max_depth=5, max_features=0.1, min_samples_split=10; total time=   1.3s
# [CV] END max_depth=5, max_features=0.1, min_samples_split=20; total time=   1.2s
# [CV] END max_depth=5, max_features=0.1, min_samples_split=20; total time=   1.2s
# [CV] END max_depth=5, max_features=0.1, min_samples_split=30; total time=   1.2s
# [CV] END max_depth=5, max_features=0.1, min_samples_split=40; total time=   1.2s
# [CV] END max_depth=5, max_features=0.1, min_samples_split=50; total time=   1.2s
# [CV] END max_depth=5, max_features=0.1, min_samples_split=50; total time=   1.2s
# [CV] END .max_depth=5, max_features=0.2, min_samples_split=2; total time=   3.1s
# [CV] END .max_depth=5, max_features=0.2, min_samples_split=5; total time=   3.1s
# [CV] END max_depth=5, max_features=0.2, min_samples_split=10; total time=   3.1s
# [CV] END max_depth=5, max_features=0.2, min_samples_split=20; total time=   3.1s
# [CV] END max_depth=5, max_features=0.2, min_samples_split=20; total time=   3.0s
# [CV] END max_depth=5, max_features=0.2, min_samples_split=30; total time=   3.1s
# [CV] END max_depth=5, max_features=0.2, min_samples_split=40; total time=   3.0s
# [CV] END max_depth=5, max_features=0.2, min_samples_split=50; total time=   3.1s
# [CV] END max_depth=7, max_features=log2, min_samples_split=2; total time=   4.0s
# [CV] END max_depth=7, max_features=log2, min_samples_split=2; total time=   4.1s
# [CV] END max_depth=7, max_features=log2, min_samples_split=5; total time=   4.0s
# [CV] END max_depth=7, max_features=log2, min_samples_split=10; total time=   4.0s
# [CV] END max_depth=7, max_features=log2, min_samples_split=20; total time=   4.0s
# [CV] END max_depth=7, max_features=log2, min_samples_split=30; total time=   4.0s
# [CV] END max_depth=7, max_features=log2, min_samples_split=30; total time=   4.1s
# [CV] END max_depth=7, max_features=log2, min_samples_split=40; total time=   4.0s
# [CV] END max_depth=7, max_features=log2, min_samples_split=50; total time=   4.0s
# [CV] END max_depth=7, max_features=sqrt, min_samples_split=2; total time=   4.1s
# [CV] END max_depth=7, max_features=sqrt, min_samples_split=5; total time=   4.1s
# [CV] END max_depth=7, max_features=sqrt, min_samples_split=5; total time=   4.3s
# [CV] END max_depth=7, max_features=sqrt, min_samples_split=10; total time=   4.1s
# [CV] END max_depth=7, max_features=sqrt, min_samples_split=20; total time=   4.1s
# [CV] END max_depth=7, max_features=sqrt, min_samples_split=30; total time=   4.1s
# [CV] END max_depth=7, max_features=sqrt, min_samples_split=40; total time=   4.1s
# [CV] END max_depth=7, max_features=sqrt, min_samples_split=40; total time=   4.1s
# [CV] END max_depth=7, max_features=sqrt, min_samples_split=50; total time=   4.0s
# [CV] END .max_depth=7, max_features=0.1, min_samples_split=2; total time=   1.6s
# [CV] END .max_depth=7, max_features=0.1, min_samples_split=5; total time=   1.6s
# [CV] END max_depth=7, max_features=0.1, min_samples_split=10; total time=   1.6s
# [CV] END max_depth=7, max_features=0.1, min_samples_split=20; total time=   1.6s
# [CV] END max_depth=7, max_features=0.1, min_samples_split=20; total time=   1.6s
# [CV] END max_depth=7, max_features=0.1, min_samples_split=30; total time=   1.6s
# [CV] END max_depth=7, max_features=0.1, min_samples_split=40; total time=   1.6s
# [CV] END max_depth=7, max_features=0.1, min_samples_split=50; total time=   1.6s
# [CV] END max_depth=7, max_features=0.1, min_samples_split=50; total time=   1.6s
# [CV] END .max_depth=7, max_features=0.2, min_samples_split=2; total time=   4.0s
# [CV] END .max_depth=7, max_features=0.2, min_samples_split=5; total time=   4.0s
# [CV] END max_depth=7, max_features=0.2, min_samples_split=10; total time=   4.1s
# [CV] END max_depth=7, max_features=0.2, min_samples_split=20; total time=   4.0s
# [CV] END max_depth=7, max_features=0.2, min_samples_split=20; total time=   4.1s
# [CV] END max_depth=7, max_features=0.2, min_samples_split=30; total time=   4.0s
# [CV] END max_depth=7, max_features=0.2, min_samples_split=40; total time=   4.1s
# [CV] END max_depth=7, max_features=0.2, min_samples_split=50; total time=   4.1s
# [CV] END max_depth=7, max_features=0.2, min_samples_split=50; total time=   4.1s
# [CV] END max_depth=10, max_features=log2, min_samples_split=2; total time=   5.4s
# [CV] END max_depth=10, max_features=log2, min_samples_split=5; total time=   5.3s
# [CV] END max_depth=10, max_features=log2, min_samples_split=10; total time=   5.3s
# [CV] END max_depth=10, max_features=log2, min_samples_split=20; total time=   5.3s
# [CV] END max_depth=10, max_features=log2, min_samples_split=20; total time=   5.3s
# [CV] END max_depth=10, max_features=log2, min_samples_split=30; total time=   5.2s
# [CV] END max_depth=10, max_features=log2, min_samples_split=40; total time=   5.3s
# [CV] END max_depth=10, max_features=log2, min_samples_split=50; total time=   5.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=2; total time=   5.4s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=2; total time=   5.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=5; total time=   5.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=10; total time=   5.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=20; total time=   5.6s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=30; total time=   5.5s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=30; total time=   5.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=40; total time=   5.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=50; total time=   5.2s
# [CV] END max_depth=10, max_features=0.1, min_samples_split=2; total time=   2.1s
# [CV] END max_depth=10, max_features=0.1, min_samples_split=2; total time=   2.1s
# [CV] END max_depth=10, max_features=0.1, min_samples_split=5; total time=   2.1s
# [CV] END max_depth=10, max_features=0.1, min_samples_split=10; total time=   2.0s
# [CV] END max_depth=10, max_features=0.1, min_samples_split=20; total time=   2.1s
# [CV] END max_depth=10, max_features=0.1, min_samples_split=30; total time=   2.0s
# [CV] END max_depth=10, max_features=0.1, min_samples_split=30; total time=   2.0s
# [CV] END max_depth=10, max_features=0.1, min_samples_split=40; total time=   2.1s
# [CV] END max_depth=10, max_features=0.1, min_samples_split=50; total time=   2.0s
# [CV] END max_depth=10, max_features=0.2, min_samples_split=2; total time=   5.3s
# [CV] END max_depth=10, max_features=0.2, min_samples_split=5; total time=   5.3s
# [CV] END max_depth=10, max_features=0.2, min_samples_split=5; total time=   5.3s
# [CV] END max_depth=10, max_features=0.2, min_samples_split=10; total time=   5.3s
# [CV] END max_depth=10, max_features=0.2, min_samples_split=20; total time=   5.3s
# [CV] END max_depth=10, max_features=0.2, min_samples_split=30; total time=   5.3s
# [CV] END max_depth=10, max_features=0.2, min_samples_split=40; total time=   5.3s
# [CV] END max_depth=10, max_features=0.2, min_samples_split=40; total time=   5.2s
# [CV] END max_depth=10, max_features=0.2, min_samples_split=50; total time=   5.2s
# [CV] END max_depth=20, max_features=log2, min_samples_split=2; total time=   7.8s
# [CV] END max_depth=20, max_features=log2, min_samples_split=5; total time=   7.6s
# [CV] END max_depth=20, max_features=log2, min_samples_split=5; total time=   7.6s
# [CV] END max_depth=20, max_features=log2, min_samples_split=10; total time=   7.3s
# [CV] END max_depth=20, max_features=log2, min_samples_split=20; total time=   7.0s
# [CV] END max_depth=20, max_features=log2, min_samples_split=30; total time=   6.8s
# [CV] END max_depth=20, max_features=log2, min_samples_split=40; total time=   6.6s
# [CV] END max_depth=20, max_features=log2, min_samples_split=40; total time=   6.6s
# [CV] END max_depth=20, max_features=log2, min_samples_split=50; total time=   6.5s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=2; total time=   7.8s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=5; total time=   7.6s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=10; total time=   7.4s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=10; total time=   7.5s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=20; total time=   7.1s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=30; total time=   6.8s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=40; total time=   6.6s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=50; total time=   6.5s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=50; total time=   6.6s
# [CV] END max_depth=20, max_features=0.1, min_samples_split=5; total time=   3.1s
# [CV] END max_depth=20, max_features=0.1, min_samples_split=10; total time=   3.0s
# [CV] END max_depth=20, max_features=0.1, min_samples_split=10; total time=   3.1s
# [CV] END max_depth=20, max_features=0.1, min_samples_split=20; total time=   2.8s
# [CV] END max_depth=20, max_features=0.1, min_samples_split=30; total time=   2.7s
# [CV] END max_depth=20, max_features=0.1, min_samples_split=40; total time=   2.6s
# [CV] END max_depth=20, max_features=0.1, min_samples_split=50; total time=   2.6s
# [CV] END max_depth=20, max_features=0.1, min_samples_split=50; total time=   2.7s
# [CV] END max_depth=20, max_features=0.2, min_samples_split=2; total time=   7.8s
# [CV] END max_depth=20, max_features=0.2, min_samples_split=5; total time=   7.8s
# [CV] END max_depth=20, max_features=0.2, min_samples_split=10; total time=   7.4s
# [CV] END max_depth=20, max_features=0.2, min_samples_split=10; total time=   7.4s
# [CV] END max_depth=20, max_features=0.2, min_samples_split=20; total time=   7.1s
# [CV] END max_depth=20, max_features=0.2, min_samples_split=30; total time=   6.8s
# [CV] END max_depth=20, max_features=0.2, min_samples_split=40; total time=   6.6s
# [CV] END max_depth=20, max_features=0.2, min_samples_split=50; total time=   6.6s
# [CV] END max_depth=30, max_features=log2, min_samples_split=2; total time=   7.9s
# [CV] END max_depth=30, max_features=log2, min_samples_split=2; total time=   8.0s
# [CV] END max_depth=30, max_features=log2, min_samples_split=5; total time=   7.7s
# [CV] END max_depth=30, max_features=log2, min_samples_split=10; total time=   7.5s
# [CV] END max_depth=30, max_features=log2, min_samples_split=20; total time=   7.2s
# [CV] END max_depth=30, max_features=log2, min_samples_split=30; total time=   6.9s
# [CV] END max_depth=30, max_features=log2, min_samples_split=30; total time=   6.9s
# [CV] END max_depth=30, max_features=log2, min_samples_split=40; total time=   6.8s
# [CV] END max_depth=30, max_features=log2, min_samples_split=50; total time=   6.6s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=2; total time=   7.9s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=5; total time=   7.8s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=5; total time=   7.9s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=10; total time=   7.6s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=20; total time=   7.2s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=30; total time=   6.9s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=40; total time=   6.8s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=40; total time=   6.6s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=50; total time=   6.6s
# [CV] END max_depth=30, max_features=0.1, min_samples_split=2; total time=   3.4s
# [CV] END max_depth=3, max_features=log2, min_samples_split=2; total time=   2.1s
# [CV] END max_depth=3, max_features=log2, min_samples_split=5; total time=   2.1s
# [CV] END max_depth=3, max_features=log2, min_samples_split=10; total time=   2.1s
# [CV] END max_depth=3, max_features=log2, min_samples_split=20; total time=   2.1s
# [CV] END max_depth=3, max_features=log2, min_samples_split=20; total time=   2.0s
# [CV] END max_depth=3, max_features=log2, min_samples_split=30; total time=   2.1s
# [CV] END max_depth=3, max_features=log2, min_samples_split=40; total time=   2.1s
# [CV] END max_depth=3, max_features=log2, min_samples_split=50; total time=   2.0s
# [CV] END max_depth=3, max_features=log2, min_samples_split=50; total time=   2.0s
# [CV] END max_depth=3, max_features=sqrt, min_samples_split=2; total time=   2.1s
# [CV] END max_depth=3, max_features=sqrt, min_samples_split=5; total time=   2.0s
# [CV] END max_depth=3, max_features=sqrt, min_samples_split=10; total time=   2.0s
# [CV] END max_depth=3, max_features=sqrt, min_samples_split=20; total time=   2.1s
# [CV] END max_depth=3, max_features=sqrt, min_samples_split=20; total time=   2.1s
# [CV] END max_depth=3, max_features=sqrt, min_samples_split=30; total time=   2.2s
# [CV] END max_depth=3, max_features=sqrt, min_samples_split=40; total time=   2.1s
# [CV] END max_depth=3, max_features=sqrt, min_samples_split=50; total time=   2.1s
# [CV] END .max_depth=3, max_features=0.1, min_samples_split=2; total time=   0.9s
# [CV] END .max_depth=3, max_features=0.1, min_samples_split=2; total time=   0.9s
# [CV] END .max_depth=3, max_features=0.1, min_samples_split=2; total time=   0.8s
# [CV] END .max_depth=3, max_features=0.1, min_samples_split=5; total time=   0.8s
# [CV] END max_depth=3, max_features=0.1, min_samples_split=10; total time=   0.9s
# [CV] END max_depth=3, max_features=0.1, min_samples_split=20; total time=   0.8s
# [CV] END max_depth=3, max_features=0.1, min_samples_split=30; total time=   0.8s
# [CV] END max_depth=3, max_features=0.1, min_samples_split=30; total time=   0.9s
# [CV] END max_depth=3, max_features=0.1, min_samples_split=40; total time=   0.8s
# [CV] END max_depth=3, max_features=0.1, min_samples_split=50; total time=   0.8s
# [CV] END .max_depth=3, max_features=0.2, min_samples_split=2; total time=   2.1s
# [CV] END .max_depth=3, max_features=0.2, min_samples_split=5; total time=   2.0s
# [CV] END .max_depth=3, max_features=0.2, min_samples_split=5; total time=   2.1s
# [CV] END max_depth=3, max_features=0.2, min_samples_split=10; total time=   2.0s
# [CV] END max_depth=3, max_features=0.2, min_samples_split=20; total time=   2.0s
# [CV] END max_depth=3, max_features=0.2, min_samples_split=30; total time=   2.1s
# [CV] END max_depth=3, max_features=0.2, min_samples_split=40; total time=   2.1s
# [CV] END max_depth=3, max_features=0.2, min_samples_split=40; total time=   2.0s
# [CV] END max_depth=3, max_features=0.2, min_samples_split=50; total time=   2.1s
# [CV] END max_depth=5, max_features=log2, min_samples_split=2; total time=   3.2s
# [CV] END max_depth=5, max_features=log2, min_samples_split=5; total time=   3.3s
# [CV] END max_depth=5, max_features=log2, min_samples_split=10; total time=   3.1s
# [CV] END max_depth=5, max_features=log2, min_samples_split=10; total time=   3.2s
# [CV] END max_depth=5, max_features=log2, min_samples_split=20; total time=   3.1s
# [CV] END max_depth=5, max_features=log2, min_samples_split=30; total time=   3.4s
# [CV] END max_depth=5, max_features=log2, min_samples_split=40; total time=   3.3s
# [CV] END max_depth=5, max_features=log2, min_samples_split=50; total time=   3.1s
# [CV] END max_depth=5, max_features=log2, min_samples_split=50; total time=   3.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_split=2; total time=   3.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_split=5; total time=   3.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_split=10; total time=   3.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_split=20; total time=   3.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_split=20; total time=   3.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_split=30; total time=   3.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_split=40; total time=   3.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_split=50; total time=   3.0s
# [CV] END .max_depth=5, max_features=0.1, min_samples_split=2; total time=   1.2s
# [CV] END .max_depth=5, max_features=0.1, min_samples_split=2; total time=   1.3s
# [CV] END .max_depth=5, max_features=0.1, min_samples_split=5; total time=   1.2s
# [CV] END max_depth=5, max_features=0.1, min_samples_split=10; total time=   1.2s
# [CV] END max_depth=5, max_features=0.1, min_samples_split=10; total time=   1.2s
# [CV] END max_depth=5, max_features=0.1, min_samples_split=20; total time=   1.2s
# [CV] END max_depth=5, max_features=0.1, min_samples_split=30; total time=   1.3s
# [CV] END max_depth=5, max_features=0.1, min_samples_split=40; total time=   1.3s
# [CV] END max_depth=5, max_features=0.1, min_samples_split=50; total time=   1.2s
# [CV] END .max_depth=5, max_features=0.2, min_samples_split=2; total time=   3.1s
# [CV] END .max_depth=5, max_features=0.2, min_samples_split=2; total time=   3.1s
# [CV] END .max_depth=5, max_features=0.2, min_samples_split=5; total time=   3.1s
# [CV] END max_depth=5, max_features=0.2, min_samples_split=10; total time=   3.1s
# [CV] END max_depth=5, max_features=0.2, min_samples_split=20; total time=   3.1s
# [CV] END max_depth=5, max_features=0.2, min_samples_split=30; total time=   3.1s
# [CV] END max_depth=5, max_features=0.2, min_samples_split=30; total time=   3.1s
# [CV] END max_depth=5, max_features=0.2, min_samples_split=40; total time=   3.1s
# [CV] END max_depth=5, max_features=0.2, min_samples_split=50; total time=   3.0s
# [CV] END max_depth=7, max_features=log2, min_samples_split=2; total time=   4.0s
# [CV] END max_depth=7, max_features=log2, min_samples_split=5; total time=   4.1s
# [CV] END max_depth=7, max_features=log2, min_samples_split=10; total time=   4.1s
# [CV] END max_depth=7, max_features=log2, min_samples_split=10; total time=   4.1s
# [CV] END max_depth=7, max_features=log2, min_samples_split=20; total time=   4.0s
# [CV] END max_depth=7, max_features=log2, min_samples_split=30; total time=   4.1s
# [CV] END max_depth=7, max_features=log2, min_samples_split=40; total time=   4.0s
# [CV] END max_depth=7, max_features=log2, min_samples_split=50; total time=   4.1s
# [CV] END max_depth=7, max_features=log2, min_samples_split=50; total time=   4.0s
# [CV] END max_depth=7, max_features=sqrt, min_samples_split=2; total time=   4.1s
# [CV] END max_depth=7, max_features=sqrt, min_samples_split=5; total time=   4.3s
# [CV] END max_depth=7, max_features=sqrt, min_samples_split=10; total time=   4.1s
# [CV] END max_depth=7, max_features=sqrt, min_samples_split=20; total time=   4.0s
# [CV] END max_depth=7, max_features=sqrt, min_samples_split=20; total time=   4.1s
# [CV] END max_depth=7, max_features=sqrt, min_samples_split=30; total time=   4.1s
# [CV] END max_depth=7, max_features=sqrt, min_samples_split=40; total time=   4.0s
# [CV] END max_depth=7, max_features=sqrt, min_samples_split=50; total time=   4.1s
# [CV] END .max_depth=7, max_features=0.1, min_samples_split=2; total time=   1.6s
# [CV] END .max_depth=7, max_features=0.1, min_samples_split=2; total time=   1.6s
# [CV] END .max_depth=7, max_features=0.1, min_samples_split=5; total time=   1.6s
# [CV] END .max_depth=7, max_features=0.1, min_samples_split=5; total time=   1.6s
# [CV] END max_depth=7, max_features=0.1, min_samples_split=10; total time=   1.6s
# [CV] END max_depth=7, max_features=0.1, min_samples_split=20; total time=   1.7s
# [CV] END max_depth=7, max_features=0.1, min_samples_split=30; total time=   1.6s
# [CV] END max_depth=7, max_features=0.1, min_samples_split=40; total time=   1.6s
# [CV] END max_depth=7, max_features=0.1, min_samples_split=40; total time=   1.6s
# [CV] END max_depth=7, max_features=0.1, min_samples_split=50; total time=   1.6s
# [CV] END .max_depth=7, max_features=0.2, min_samples_split=2; total time=   4.1s
# [CV] END .max_depth=7, max_features=0.2, min_samples_split=5; total time=   4.1s
# [CV] END max_depth=7, max_features=0.2, min_samples_split=10; total time=   4.1s
# [CV] END max_depth=7, max_features=0.2, min_samples_split=10; total time=   4.1s
# [CV] END max_depth=7, max_features=0.2, min_samples_split=20; total time=   4.1s
# [CV] END max_depth=7, max_features=0.2, min_samples_split=30; total time=   4.1s
# [CV] END max_depth=7, max_features=0.2, min_samples_split=40; total time=   4.1s
# [CV] END max_depth=7, max_features=0.2, min_samples_split=50; total time=   4.1s
# [CV] END max_depth=10, max_features=log2, min_samples_split=2; total time=   5.3s
# [CV] END max_depth=10, max_features=log2, min_samples_split=2; total time=   5.3s
# [CV] END max_depth=10, max_features=log2, min_samples_split=5; total time=   5.3s
# [CV] END max_depth=10, max_features=log2, min_samples_split=10; total time=   5.4s
# [CV] END max_depth=10, max_features=log2, min_samples_split=20; total time=   5.3s
# [CV] END max_depth=10, max_features=log2, min_samples_split=30; total time=   5.3s
# [CV] END max_depth=10, max_features=log2, min_samples_split=30; total time=   5.3s
# [CV] END max_depth=10, max_features=log2, min_samples_split=40; total time=   5.2s
# [CV] END max_depth=10, max_features=log2, min_samples_split=50; total time=   5.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=2; total time=   5.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=5; total time=   5.4s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=5; total time=   5.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=10; total time=   5.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=20; total time=   5.7s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=30; total time=   5.4s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=40; total time=   5.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=40; total time=   5.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=50; total time=   5.3s
# [CV] END max_depth=10, max_features=0.1, min_samples_split=2; total time=   2.1s
# [CV] END max_depth=10, max_features=0.1, min_samples_split=5; total time=   2.1s
# [CV] END max_depth=10, max_features=0.1, min_samples_split=10; total time=   2.1s
# [CV] END max_depth=10, max_features=0.1, min_samples_split=20; total time=   2.1s
# [CV] END max_depth=10, max_features=0.1, min_samples_split=20; total time=   2.1s
# [CV] END max_depth=10, max_features=0.1, min_samples_split=30; total time=   2.1s
# [CV] END max_depth=10, max_features=0.1, min_samples_split=40; total time=   2.1s
# [CV] END max_depth=10, max_features=0.1, min_samples_split=50; total time=   2.0s
# [CV] END max_depth=10, max_features=0.2, min_samples_split=2; total time=   5.4s
# [CV] END max_depth=10, max_features=0.2, min_samples_split=2; total time=   5.4s
# [CV] END max_depth=10, max_features=0.2, min_samples_split=5; total time=   5.3s
# [CV] END max_depth=10, max_features=0.2, min_samples_split=10; total time=   5.3s
# [CV] END max_depth=10, max_features=0.2, min_samples_split=20; total time=   5.3s
# [CV] END max_depth=10, max_features=0.2, min_samples_split=30; total time=   5.3s
# [CV] END max_depth=10, max_features=0.2, min_samples_split=30; total time=   5.3s
# [CV] END max_depth=10, max_features=0.2, min_samples_split=40; total time=   5.3s
# [CV] END max_depth=10, max_features=0.2, min_samples_split=50; total time=   5.3s
# [CV] END max_depth=20, max_features=log2, min_samples_split=2; total time=   7.9s
# [CV] END max_depth=20, max_features=log2, min_samples_split=5; total time=   7.7s
# [CV] END max_depth=20, max_features=log2, min_samples_split=10; total time=   7.5s
# [CV] END max_depth=20, max_features=log2, min_samples_split=10; total time=   7.5s
# [CV] END max_depth=20, max_features=log2, min_samples_split=20; total time=   7.1s
# [CV] END max_depth=20, max_features=log2, min_samples_split=30; total time=   6.9s
# [CV] END max_depth=20, max_features=log2, min_samples_split=40; total time=   6.6s
# [CV] END max_depth=20, max_features=log2, min_samples_split=50; total time=   6.5s
# [CV] END max_depth=20, max_features=log2, min_samples_split=50; total time=   6.6s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=2; total time=   7.8s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=5; total time=   7.7s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=10; total time=   7.5s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=20; total time=   7.2s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=20; total time=   7.1s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=30; total time=   6.9s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=40; total time=   6.6s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=50; total time=   6.5s
# [CV] END max_depth=20, max_features=0.1, min_samples_split=2; total time=   3.2s
# [CV] END max_depth=20, max_features=0.1, min_samples_split=2; total time=   3.2s
# [CV] END max_depth=20, max_features=0.1, min_samples_split=5; total time=   3.1s
# [CV] END max_depth=20, max_features=0.1, min_samples_split=10; total time=   3.0s
# [CV] END max_depth=20, max_features=0.1, min_samples_split=10; total time=   3.0s
# [CV] END max_depth=20, max_features=0.1, min_samples_split=20; total time=   2.8s
# [CV] END max_depth=20, max_features=0.1, min_samples_split=30; total time=   2.8s
# [CV] END max_depth=20, max_features=0.1, min_samples_split=40; total time=   2.6s
# [CV] END max_depth=20, max_features=0.1, min_samples_split=50; total time=   2.6s
# [CV] END max_depth=20, max_features=0.1, min_samples_split=50; total time=   2.6s
# [CV] END max_depth=20, max_features=0.2, min_samples_split=2; total time=   7.9s
# [CV] END max_depth=20, max_features=0.2, min_samples_split=5; total time=   7.9s
# [CV] END max_depth=20, max_features=0.2, min_samples_split=10; total time=   7.4s
# [CV] END max_depth=20, max_features=0.2, min_samples_split=20; total time=   7.1s
# [CV] END max_depth=20, max_features=0.2, min_samples_split=20; total time=   7.1s
# [CV] END max_depth=20, max_features=0.2, min_samples_split=30; total time=   6.9s
# [CV] END max_depth=20, max_features=0.2, min_samples_split=40; total time=   6.7s
# [CV] END max_depth=20, max_features=0.2, min_samples_split=50; total time=   6.6s
# [CV] END max_depth=30, max_features=log2, min_samples_split=2; total time=   8.2s
# [CV] END max_depth=30, max_features=log2, min_samples_split=2; total time=   8.0s
# [CV] END max_depth=30, max_features=log2, min_samples_split=5; total time=   8.0s
# [CV] END max_depth=30, max_features=log2, min_samples_split=10; total time=   7.6s
# [CV] END max_depth=30, max_features=log2, min_samples_split=20; total time=   7.1s
# [CV] END max_depth=30, max_features=log2, min_samples_split=30; total time=   7.0s
# [CV] END max_depth=30, max_features=log2, min_samples_split=30; total time=   7.0s
# [CV] END max_depth=30, max_features=log2, min_samples_split=40; total time=   6.8s
# [CV] END max_depth=30, max_features=log2, min_samples_split=50; total time=   6.6s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=2; total time=   8.0s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=5; total time=   8.0s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=5; total time=   7.8s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=10; total time=   7.6s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=20; total time=   7.3s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=30; total time=   6.9s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=40; total time=   6.7s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=40; total time=   6.8s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=50; total time=   6.6s
# [CV] END max_depth=30, max_features=0.1, min_samples_split=2; total time=   3.5s
# [CV] END max_depth=3, max_features=log2, min_samples_split=2; total time=   2.0s
# ...
# [CV] END max_depth=3, max_features=log2, min_samples_split=50; total time=   2.0s
# [CV] END max_depth=3, max_features=sqrt, min_samples_split=2; total time=   2.0s
# [CV] END max_depth=3, max_features=sqrt, min_samples_split=5; total time=   2.0s
# [CV] END max_depth=3, max_features=sqrt, min_samples_split=5; total time=   2.0s
# [CV] END max_depth=3, max_features=sqrt, min_samples_split=10; total time=   2.0s
# [CV] END max_depth=3, max_features=sqrt, min_samples_split=20; total time=   2.2s
# [CV] END max_depth=3, max_features=sqrt, min_samples_split=30; total time=   2.2s
# [CV] END max_depth=3, max_features=sqrt, min_samples_split=40; total time=   2.1s
# [CV] END max_depth=3, max_features=sqrt, min_samples_split=40; total time=   2.1s
# [CV] END max_depth=3, max_features=sqrt, min_samples_split=50; total time=   2.0s
# [CV] END .max_depth=3, max_features=0.1, min_samples_split=5; total time=   0.9s
# [CV] END .max_depth=3, max_features=0.1, min_samples_split=5; total time=   0.9s
# [CV] END max_depth=3, max_features=0.1, min_samples_split=10; total time=   0.9s
# [CV] END max_depth=3, max_features=0.1, min_samples_split=20; total time=   0.8s
# [CV] END max_depth=3, max_features=0.1, min_samples_split=30; total time=   0.8s
# [CV] END max_depth=3, max_features=0.1, min_samples_split=40; total time=   0.8s
# [CV] END max_depth=3, max_features=0.1, min_samples_split=50; total time=   0.9s
# [CV] END max_depth=3, max_features=0.1, min_samples_split=50; total time=   0.8s
# [CV] END .max_depth=3, max_features=0.2, min_samples_split=2; total time=   2.0s
# [CV] END .max_depth=3, max_features=0.2, min_samples_split=5; total time=   2.0s
# [CV] END max_depth=3, max_features=0.2, min_samples_split=10; total time=   2.0s
# [CV] END max_depth=3, max_features=0.2, min_samples_split=10; total time=   2.0s
# [CV] END max_depth=3, max_features=0.2, min_samples_split=20; total time=   2.0s
# [CV] END max_depth=3, max_features=0.2, min_samples_split=30; total time=   2.2s
# [CV] END max_depth=3, max_features=0.2, min_samples_split=40; total time=   2.0s
# [CV] END max_depth=3, max_features=0.2, min_samples_split=50; total time=   2.0s
# [CV] END max_depth=5, max_features=log2, min_samples_split=2; total time=   3.4s
# [CV] END max_depth=5, max_features=log2, min_samples_split=2; total time=   3.3s
# [CV] END max_depth=5, max_features=log2, min_samples_split=5; total time=   3.1s
# [CV] END max_depth=5, max_features=log2, min_samples_split=10; total time=   3.2s
# [CV] END max_depth=5, max_features=log2, min_samples_split=20; total time=   3.1s
# [CV] END max_depth=5, max_features=log2, min_samples_split=30; total time=   3.3s
# [CV] END max_depth=5, max_features=log2, min_samples_split=30; total time=   3.3s
# [CV] END max_depth=5, max_features=log2, min_samples_split=40; total time=   3.2s
# [CV] END max_depth=5, max_features=log2, min_samples_split=50; total time=   3.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_split=2; total time=   3.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_split=5; total time=   3.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_split=5; total time=   3.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_split=10; total time=   3.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_split=20; total time=   3.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_split=30; total time=   3.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_split=40; total time=   3.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_split=40; total time=   3.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_split=50; total time=   3.1s
# [CV] END .max_depth=5, max_features=0.1, min_samples_split=2; total time=   1.2s
# [CV] END .max_depth=5, max_features=0.1, min_samples_split=5; total time=   1.2s
# [CV] END .max_depth=5, max_features=0.1, min_samples_split=5; total time=   1.3s
# [CV] END max_depth=5, max_features=0.1, min_samples_split=10; total time=   1.2s
# [CV] END max_depth=5, max_features=0.1, min_samples_split=20; total time=   1.2s
# [CV] END max_depth=5, max_features=0.1, min_samples_split=30; total time=   1.3s
# [CV] END max_depth=5, max_features=0.1, min_samples_split=40; total time=   1.2s
# [CV] END max_depth=5, max_features=0.1, min_samples_split=40; total time=   1.2s
# [CV] END max_depth=5, max_features=0.1, min_samples_split=50; total time=   1.2s
# [CV] END .max_depth=5, max_features=0.2, min_samples_split=2; total time=   3.0s
# [CV] END .max_depth=5, max_features=0.2, min_samples_split=5; total time=   3.1s
# [CV] END max_depth=5, max_features=0.2, min_samples_split=10; total time=   3.1s
# [CV] END max_depth=5, max_features=0.2, min_samples_split=10; total time=   3.0s
# [CV] END max_depth=5, max_features=0.2, min_samples_split=20; total time=   3.1s
# [CV] END max_depth=5, max_features=0.2, min_samples_split=30; total time=   3.0s
# [CV] END max_depth=5, max_features=0.2, min_samples_split=40; total time=   3.1s
# [CV] END max_depth=5, max_features=0.2, min_samples_split=50; total time=   3.1s
# [CV] END max_depth=5, max_features=0.2, min_samples_split=50; total time=   3.1s
# [CV] END max_depth=7, max_features=log2, min_samples_split=2; total time=   4.0s
# [CV] END max_depth=7, max_features=log2, min_samples_split=5; total time=   4.0s
# [CV] END max_depth=7, max_features=log2, min_samples_split=10; total time=   4.1s
# [CV] END max_depth=7, max_features=log2, min_samples_split=20; total time=   4.0s
# [CV] END max_depth=7, max_features=log2, min_samples_split=20; total time=   4.0s
# [CV] END max_depth=7, max_features=log2, min_samples_split=30; total time=   4.1s
# [CV] END max_depth=7, max_features=log2, min_samples_split=40; total time=   4.1s
# [CV] END max_depth=7, max_features=log2, min_samples_split=50; total time=   4.1s
# [CV] END max_depth=7, max_features=sqrt, min_samples_split=2; total time=   4.1s
# [CV] END max_depth=7, max_features=sqrt, min_samples_split=2; total time=   4.0s
# [CV] END max_depth=7, max_features=sqrt, min_samples_split=5; total time=   4.3s
# [CV] END max_depth=7, max_features=sqrt, min_samples_split=10; total time=   4.0s
# [CV] END max_depth=7, max_features=sqrt, min_samples_split=20; total time=   4.0s
# [CV] END max_depth=7, max_features=sqrt, min_samples_split=30; total time=   4.1s
# [CV] END max_depth=7, max_features=sqrt, min_samples_split=30; total time=   4.0s
# [CV] END max_depth=7, max_features=sqrt, min_samples_split=40; total time=   4.0s
# [CV] END max_depth=7, max_features=sqrt, min_samples_split=50; total time=   4.0s
# [CV] END .max_depth=7, max_features=0.1, min_samples_split=2; total time=   1.6s
# [CV] END .max_depth=7, max_features=0.1, min_samples_split=2; total time=   1.6s
# [CV] END .max_depth=7, max_features=0.1, min_samples_split=5; total time=   1.6s
# [CV] END max_depth=7, max_features=0.1, min_samples_split=10; total time=   1.6s
# [CV] END max_depth=7, max_features=0.1, min_samples_split=20; total time=   1.6s
# [CV] END max_depth=7, max_features=0.1, min_samples_split=30; total time=   1.6s
# [CV] END max_depth=7, max_features=0.1, min_samples_split=30; total time=   1.6s
# [CV] END max_depth=7, max_features=0.1, min_samples_split=40; total time=   1.6s
# [CV] END max_depth=7, max_features=0.1, min_samples_split=50; total time=   1.6s
# [CV] END .max_depth=7, max_features=0.2, min_samples_split=2; total time=   4.1s
# [CV] END .max_depth=7, max_features=0.2, min_samples_split=5; total time=   4.1s
# [CV] END .max_depth=7, max_features=0.2, min_samples_split=5; total time=   4.1s
# [CV] END max_depth=7, max_features=0.2, min_samples_split=10; total time=   4.0s
# [CV] END max_depth=7, max_features=0.2, min_samples_split=20; total time=   4.0s[CV] END max_depth=3, max_features=log2, min_samples_split=2; total time=   2.0s
# [CV] END max_depth=3, max_features=log2, min_samples_split=2; total time=   2.1s
# [CV] END max_depth=3, max_features=log2, min_samples_split=5; total time=   2.0s
# [CV] END max_depth=3, max_features=log2, min_samples_split=10; total time=   2.1s
# [CV] END max_depth=3, max_features=log2, min_samples_split=20; total time=   2.0s
# [CV] END max_depth=3, max_features=log2, min_samples_split=30; total time=   2.1s
# [CV] END max_depth=3, max_features=log2, min_samples_split=30; total time=   2.0s
# [CV] END max_depth=3, max_features=log2, min_samples_split=40; total time=   2.1s
# [CV] END max_depth=3, max_features=log2, min_samples_split=50; total time=   2.0s
# [CV] END max_depth=3, max_features=sqrt, min_samples_split=2; total time=   2.1s
# [CV] END max_depth=3, max_features=sqrt, min_samples_split=5; total time=   2.0s
# [CV] END max_depth=3, max_features=sqrt, min_samples_split=10; total time=   2.0s
# [CV] END max_depth=3, max_features=sqrt, min_samples_split=10; total time=   2.0s
# [CV] END max_depth=3, max_features=sqrt, min_samples_split=20; total time=   2.2s
# [CV] END max_depth=3, max_features=sqrt, min_samples_split=30; total time=   2.2s
# [CV] END max_depth=3, max_features=sqrt, min_samples_split=40; total time=   2.1s
# [CV] END max_depth=3, max_features=sqrt, min_samples_split=50; total time=   2.1s
# [CV] END max_depth=3, max_features=sqrt, min_samples_split=50; total time=   2.2s
# [CV] END .max_depth=3, max_features=0.1, min_samples_split=5; total time=   0.8s
# [CV] END max_depth=3, max_features=0.1, min_samples_split=10; total time=   0.8s
# [CV] END max_depth=3, max_features=0.1, min_samples_split=20; total time=   0.8s
# [CV] END max_depth=3, max_features=0.1, min_samples_split=20; total time=   0.8s
# [CV] END max_depth=3, max_features=0.1, min_samples_split=30; total time=   0.8s
# [CV] END max_depth=3, max_features=0.1, min_samples_split=40; total time=   0.8s
# [CV] END max_depth=3, max_features=0.1, min_samples_split=50; total time=   0.8s
# [CV] END .max_depth=3, max_features=0.2, min_samples_split=2; total time=   2.1s
# [CV] END .max_depth=3, max_features=0.2, min_samples_split=2; total time=   2.1s
# [CV] END .max_depth=3, max_features=0.2, min_samples_split=5; total time=   2.1s
# [CV] END max_depth=3, max_features=0.2, min_samples_split=10; total time=   2.0s
# [CV] END max_depth=3, max_features=0.2, min_samples_split=20; total time=   2.0s
# [CV] END max_depth=3, max_features=0.2, min_samples_split=30; total time=   2.1s
# [CV] END max_depth=3, max_features=0.2, min_samples_split=30; total time=   2.0s
# [CV] END max_depth=3, max_features=0.2, min_samples_split=40; total time=   2.0s
# [CV] END max_depth=3, max_features=0.2, min_samples_split=50; total time=   2.1s
# [CV] END max_depth=5, max_features=log2, min_samples_split=2; total time=   3.4s
# [CV] END max_depth=5, max_features=log2, min_samples_split=5; total time=   3.3s
# [CV] END max_depth=5, max_features=log2, min_samples_split=5; total time=   3.0s
# [CV] END max_depth=5, max_features=log2, min_samples_split=10; total time=   3.2s
# [CV] END max_depth=5, max_features=log2, min_samples_split=20; total time=   3.1s
# [CV] END max_depth=5, max_features=log2, min_samples_split=30; total time=   3.3s
# [CV] END max_depth=5, max_features=log2, min_samples_split=40; total time=   3.3s
# [CV] END max_depth=5, max_features=log2, min_samples_split=40; total time=   3.1s
# [CV] END max_depth=5, max_features=log2, min_samples_split=50; total time=   3.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_split=2; total time=   3.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_split=5; total time=   3.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_split=10; total time=   3.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_split=10; total time=   3.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_split=20; total time=   3.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_split=30; total time=   3.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_split=40; total time=   3.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_split=50; total time=   3.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_split=50; total time=   3.1s
# [CV] END .max_depth=5, max_features=0.1, min_samples_split=5; total time=   1.2s
# [CV] END max_depth=5, max_features=0.1, min_samples_split=10; total time=   1.2s
# [CV] END max_depth=5, max_features=0.1, min_samples_split=10; total time=   1.2s
# [CV] END max_depth=5, max_features=0.1, min_samples_split=20; total time=   1.2s
# [CV] END max_depth=5, max_features=0.1, min_samples_split=30; total time=   1.2s
# [CV] END max_depth=5, max_features=0.1, min_samples_split=40; total time=   1.2s
# [CV] END max_depth=5, max_features=0.1, min_samples_split=50; total time=   1.2s
# [CV] END max_depth=5, max_features=0.1, min_samples_split=50; total time=   1.2s
# [CV] END .max_depth=5, max_features=0.2, min_samples_split=2; total time=   3.0s
# [CV] END .max_depth=5, max_features=0.2, min_samples_split=5; total time=   3.0s
# [CV] END max_depth=5, max_features=0.2, min_samples_split=10; total time=   3.0s
# [CV] END max_depth=5, max_features=0.2, min_samples_split=20; total time=   3.0s
# [CV] END max_depth=5, max_features=0.2, min_samples_split=20; total time=   3.1s
# [CV] END max_depth=5, max_features=0.2, min_samples_split=30; total time=   3.1s
# [CV] END max_depth=5, max_features=0.2, min_samples_split=40; total time=   3.1s
# [CV] END max_depth=5, max_features=0.2, min_samples_split=50; total time=   3.1s
# [CV] END max_depth=7, max_features=log2, min_samples_split=2; total time=   4.1s
# [CV] END max_depth=7, max_features=log2, min_samples_split=2; total time=   4.0s
# [CV] END max_depth=7, max_features=log2, min_samples_split=5; total time=   4.0s
# [CV] END max_depth=7, max_features=log2, min_samples_split=10; total time=   4.1s
# [CV] END max_depth=7, max_features=log2, min_samples_split=20; total time=   4.0s
# [CV] END max_depth=7, max_features=log2, min_samples_split=30; total time=   4.0s
# [CV] END max_depth=7, max_features=log2, min_samples_split=30; total time=   4.1s
# [CV] END max_depth=7, max_features=log2, min_samples_split=40; total time=   4.0s
# [CV] END max_depth=7, max_features=log2, min_samples_split=50; total time=   4.0s
# [CV] END max_depth=7, max_features=sqrt, min_samples_split=2; total time=   4.1s
# [CV] END max_depth=7, max_features=sqrt, min_samples_split=5; total time=   4.1s
# [CV] END max_depth=7, max_features=sqrt, min_samples_split=5; total time=   4.3s
# [CV] END max_depth=7, max_features=sqrt, min_samples_split=10; total time=   4.0s
# [CV] END max_depth=7, max_features=sqrt, min_samples_split=20; total time=   4.1s
# [CV] END max_depth=7, max_features=sqrt, min_samples_split=30; total time=   4.0s
# [CV] END max_depth=7, max_features=sqrt, min_samples_split=40; total time=   4.0s
# [CV] END max_depth=7, max_features=sqrt, min_samples_split=40; total time=   4.1s
# [CV] END max_depth=7, max_features=sqrt, min_samples_split=50; total time=   4.0s
# [CV] END .max_depth=7, max_features=0.1, min_samples_split=2; total time=   1.6s
# [CV] END .max_depth=7, max_features=0.1, min_samples_split=5; total time=   1.6s
# [CV] END .max_depth=7, max_features=0.1, min_samples_split=5; total time=   1.7s
# [CV] END max_depth=7, max_features=0.1, min_samples_split=10; total time=   1.6s
# [CV] END max_depth=7, max_features=0.1, min_samples_split=20; total time=   1.6s
# [CV] END max_depth=7, max_features=0.1, min_samples_split=30; total time=   1.6s
# [CV] END max_depth=7, max_features=0.1, min_samples_split=40; total time=   1.6s
# [CV] END max_depth=7, max_features=0.1, min_samples_split=40; total time=   1.6s
# [CV] END max_depth=7, max_features=0.1, min_samples_split=50; total time=   1.6s
# [CV] END .max_depth=7, max_features=0.2, min_samples_split=2; total time=   4.0s
# [CV] END .max_depth=7, max_features=0.2, min_samples_split=5; total time=   4.0s
# [CV] END max_depth=7, max_features=0.2, min_samples_split=10; total time=   4.0s
# [CV] END max_depth=7, max_features=0.2, min_samples_split=10; total time=   4.0s
# [CV] END max_depth=7, max_features=0.2, min_samples_split=20; total time=   4.1s
# [CV] END max_depth=7, max_features=0.2, min_samples_split=30; total time=   4.1s
# /Users/sherrywang/anaconda3/lib/python3.12/site-packages/numpy/ma/core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,

# %%
# loop through and print the results
for key, value in random_forest_result.items():
    print(f"{key}: \n {value}")
# Out:
# best_params:
#  {'max_depth': 30, 'max_features': 'log2', 'min_samples_split': 5}
# best_score:
#  0.5836847387730483
# best_model:
#  RandomForestClassifier(max_depth=30, max_features='log2', min_samples_split=5,
#                        random_state=2024)

# %%
import numpy as np

test_labels_encoded = label_encoder.fit_transform(test_labels)
rf =  RandomForestClassifier(max_depth=30, max_features='log2', min_samples_split=5,
                       random_state=2024)

rf.fit(X_train_pca, train_labels_encoded)
test_Class_pred = rf.predict(transformed_features_test)
print(classification_report(test_labels_encoded, test_Class_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.37      0.47      0.41       958
#            1       0.00      0.00      0.00       111
#            2       0.63      0.63      0.63      1024
#            3       0.70      0.85      0.77      1774
#            4       0.43      0.40      0.41      1233
#            5       0.39      0.45      0.41      1247
#            6       0.47      0.13      0.21       831
#
#     accuracy                           0.52      7178
#    macro avg       0.43      0.42      0.41      7178
# weighted avg       0.51      0.52      0.50      7178
# /Users/sherrywang/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sherrywang/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sherrywang/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [CV] END max_depth=7, max_features=0.2, min_samples_split=40; total time=   4.0s
# [CV] END max_depth=7, max_features=0.2, min_samples_split=50; total time=   4.0s
# [CV] END max_depth=7, max_features=0.2, min_samples_split=50; total time=   4.0s
# [CV] END max_depth=10, max_features=log2, min_samples_split=2; total time=   5.3s
# [CV] END max_depth=10, max_features=log2, min_samples_split=5; total time=   5.3s
# [CV] END max_depth=10, max_features=log2, min_samples_split=10; total time=   5.3s
# [CV] END max_depth=10, max_features=log2, min_samples_split=20; total time=   5.4s
# [CV] END max_depth=10, max_features=log2, min_samples_split=20; total time=   5.3s
# [CV] END max_depth=10, max_features=log2, min_samples_split=30; total time=   5.2s
# [CV] END max_depth=10, max_features=log2, min_samples_split=40; total time=   5.2s
# [CV] END max_depth=10, max_features=log2, min_samples_split=50; total time=   5.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=2; total time=   5.4s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=2; total time=   5.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=5; total time=   5.4s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=10; total time=   5.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=20; total time=   5.5s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=30; total time=   5.5s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=30; total time=   5.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=40; total time=   5.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=50; total time=   5.2s
# [CV] END max_depth=10, max_features=0.1, min_samples_split=2; total time=   2.1s
# [CV] END max_depth=10, max_features=0.1, min_samples_split=2; total time=   2.1s
# [CV] END max_depth=10, max_features=0.1, min_samples_split=5; total time=   2.1s
# [CV] END max_depth=10, max_features=0.1, min_samples_split=10; total time=   2.1s
# [CV] END max_depth=10, max_features=0.1, min_samples_split=20; total time=   2.1s
# [CV] END max_depth=10, max_features=0.1, min_samples_split=20; total time=   2.1s
# [CV] END max_depth=10, max_features=0.1, min_samples_split=30; total time=   2.1s
# [CV] END max_depth=10, max_features=0.1, min_samples_split=40; total time=   2.1s
# [CV] END max_depth=10, max_features=0.1, min_samples_split=50; total time=   2.0s
# [CV] END max_depth=10, max_features=0.2, min_samples_split=2; total time=   5.3s
# [CV] END max_depth=10, max_features=0.2, min_samples_split=2; total time=   5.4s
# [CV] END max_depth=10, max_features=0.2, min_samples_split=5; total time=   5.3s
# [CV] END max_depth=10, max_features=0.2, min_samples_split=10; total time=   5.3s
# [CV] END max_depth=10, max_features=0.2, min_samples_split=20; total time=   5.3s
# [CV] END max_depth=10, max_features=0.2, min_samples_split=30; total time=   5.2s
# [CV] END max_depth=10, max_features=0.2, min_samples_split=30; total time=   5.3s
# [CV] END max_depth=10, max_features=0.2, min_samples_split=40; total time=   5.2s
# [CV] END max_depth=10, max_features=0.2, min_samples_split=50; total time=   5.2s
# [CV] END max_depth=20, max_features=log2, min_samples_split=2; total time=   7.7s
# [CV] END max_depth=20, max_features=log2, min_samples_split=5; total time=   7.6s
# [CV] END max_depth=20, max_features=log2, min_samples_split=5; total time=   7.7s
# [CV] END max_depth=20, max_features=log2, min_samples_split=10; total time=   7.4s
# [CV] END max_depth=20, max_features=log2, min_samples_split=20; total time=   7.2s
# [CV] END max_depth=20, max_features=log2, min_samples_split=30; total time=   6.8s
# [CV] END max_depth=20, max_features=log2, min_samples_split=40; total time=   6.7s
# [CV] END max_depth=20, max_features=log2, min_samples_split=40; total time=   6.7s
# [CV] END max_depth=20, max_features=log2, min_samples_split=50; total time=   6.6s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=2; total time=   7.7s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=5; total time=   7.6s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=10; total time=   7.5s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=20; total time=   7.1s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=20; total time=   7.1s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=30; total time=   6.8s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=40; total time=   6.6s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=50; total time=   6.5s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=50; total time=   6.5s
# [CV] END max_depth=20, max_features=0.1, min_samples_split=5; total time=   3.2s
# [CV] END max_depth=20, max_features=0.1, min_samples_split=5; total time=   3.1s
# [CV] END max_depth=20, max_features=0.1, min_samples_split=10; total time=   3.0s
# [CV] END max_depth=20, max_features=0.1, min_samples_split=20; total time=   2.8s
# [CV] END max_depth=20, max_features=0.1, min_samples_split=30; total time=   2.8s
# [CV] END max_depth=20, max_features=0.1, min_samples_split=40; total time=   2.7s
# [CV] END max_depth=20, max_features=0.1, min_samples_split=50; total time=   2.6s
# [CV] END max_depth=20, max_features=0.2, min_samples_split=2; total time=   7.9s
# [CV] END max_depth=20, max_features=0.2, min_samples_split=2; total time=   7.9s
# [CV] END max_depth=20, max_features=0.2, min_samples_split=5; total time=   7.7s
# [CV] END max_depth=20, max_features=0.2, min_samples_split=10; total time=   7.4s
# [CV] END max_depth=20, max_features=0.2, min_samples_split=20; total time=   7.1s
# [CV] END max_depth=20, max_features=0.2, min_samples_split=30; total time=   6.8s
# [CV] END max_depth=20, max_features=0.2, min_samples_split=30; total time=   6.7s
# [CV] END max_depth=20, max_features=0.2, min_samples_split=40; total time=   6.6s
# [CV] END max_depth=20, max_features=0.2, min_samples_split=50; total time=   6.4s
# [CV] END max_depth=30, max_features=log2, min_samples_split=2; total time=   8.0s
# [CV] END max_depth=30, max_features=log2, min_samples_split=5; total time=   7.8s
# [CV] END max_depth=30, max_features=log2, min_samples_split=5; total time=   7.8s
# [CV] END max_depth=30, max_features=log2, min_samples_split=10; total time=   7.6s
# [CV] END max_depth=30, max_features=log2, min_samples_split=20; total time=   7.2s
# [CV] END max_depth=30, max_features=log2, min_samples_split=30; total time=   6.9s
# [CV] END max_depth=30, max_features=log2, min_samples_split=40; total time=   6.7s
# [CV] END max_depth=30, max_features=log2, min_samples_split=40; total time=   6.8s
# [CV] END max_depth=30, max_features=log2, min_samples_split=50; total time=   6.6s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=2; total time=   8.0s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=5; total time=   7.7s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=10; total time=   7.6s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=10; total time=   7.5s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=20; total time=   7.3s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=30; total time=   6.9s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=40; total time=   6.8s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=50; total time=   6.5s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=50; total time=   6.7s
# [CV] END max_depth=30, max_features=0.1, min_samples_split=5; total time=   3.5s
# [CV] END max_depth=30, max_features=0.1, min_samples_split=5; total time=   3.2s
# [CV] END max_depth=30, max_features=0.1, min_samples_split=10; total time=   3.1s
# [CV] END max_depth=30, max_features=0.1, min_samples_split=20; total time=   2.9s
# [CV] END max_depth=30, max_features=0.1, min_samples_split=30; total time=   2.8s
# [CV] END max_depth=30, max_features=0.1, min_samples_split=40; total time=   2.7s
# [CV] END max_depth=30, max_features=0.1, min_samples_split=40; total time=   2.7s
# [CV] END max_depth=30, max_features=0.1, min_samples_split=50; total time=   2.7s
# [CV] END max_depth=30, max_features=0.2, min_samples_split=2; total time=   8.0s
# [CV] END max_depth=30, max_features=0.2, min_samples_split=5; total time=   7.9s
# [CV] END max_depth=30, max_features=0.2, min_samples_split=10; total time=   7.7s
# [CV] END max_depth=30, max_features=0.2, min_samples_split=20; total time=   7.2s
# [CV] END max_depth=30, max_features=0.2, min_samples_split=20; total time=   7.3s
# [CV] END max_depth=30, max_features=0.2, min_samples_split=30; total time=   6.9s
# [CV] END max_depth=30, max_features=0.2, min_samples_split=40; total time=   6.7s
# [CV] END max_depth=30, max_features=0.2, min_samples_split=50; total time=   6.5s
#
# [CV] END max_depth=7, max_features=0.2, min_samples_split=30; total time=   4.0s
# [CV] END max_depth=7, max_features=0.2, min_samples_split=40; total time=   4.1s
# [CV] END max_depth=7, max_features=0.2, min_samples_split=40; total time=   4.0s
# [CV] END max_depth=7, max_features=0.2, min_samples_split=50; total time=   4.1s
# [CV] END max_depth=10, max_features=log2, min_samples_split=2; total time=   5.4s
# [CV] END max_depth=10, max_features=log2, min_samples_split=5; total time=   5.3s
# [CV] END max_depth=10, max_features=log2, min_samples_split=10; total time=   5.4s
# [CV] END max_depth=10, max_features=log2, min_samples_split=10; total time=   5.4s
# [CV] END max_depth=10, max_features=log2, min_samples_split=20; total time=   5.3s
# [CV] END max_depth=10, max_features=log2, min_samples_split=30; total time=   5.3s
# [CV] END max_depth=10, max_features=log2, min_samples_split=40; total time=   5.2s
# [CV] END max_depth=10, max_features=log2, min_samples_split=50; total time=   5.2s
# [CV] END max_depth=10, max_features=log2, min_samples_split=50; total time=   5.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=2; total time=   5.4s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=5; total time=   5.4s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=10; total time=   5.4s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=20; total time=   5.4s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=20; total time=   5.7s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=30; total time=   5.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=40; total time=   5.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=50; total time=   5.3s
# [CV] END max_depth=10, max_features=0.1, min_samples_split=2; total time=   2.0s
# [CV] END max_depth=10, max_features=0.1, min_samples_split=2; total time=   2.1s
# [CV] END max_depth=10, max_features=0.1, min_samples_split=5; total time=   2.1s
# [CV] END max_depth=10, max_features=0.1, min_samples_split=5; total time=   2.1s
# [CV] END max_depth=10, max_features=0.1, min_samples_split=10; total time=   2.1s
# [CV] END max_depth=10, max_features=0.1, min_samples_split=20; total time=   2.0s
# [CV] END max_depth=10, max_features=0.1, min_samples_split=30; total time=   2.0s
# [CV] END max_depth=10, max_features=0.1, min_samples_split=40; total time=   2.1s
# [CV] END max_depth=10, max_features=0.1, min_samples_split=40; total time=   2.0s
# [CV] END max_depth=10, max_features=0.1, min_samples_split=50; total time=   2.0s
# [CV] END max_depth=10, max_features=0.2, min_samples_split=2; total time=   5.3s
# [CV] END max_depth=10, max_features=0.2, min_samples_split=5; total time=   5.3s
# [CV] END max_depth=10, max_features=0.2, min_samples_split=10; total time=   5.4s
# [CV] END max_depth=10, max_features=0.2, min_samples_split=10; total time=   5.3s
# [CV] END max_depth=10, max_features=0.2, min_samples_split=20; total time=   5.3s
# [CV] END max_depth=10, max_features=0.2, min_samples_split=30; total time=   5.2s
# [CV] END max_depth=10, max_features=0.2, min_samples_split=40; total time=   5.3s
# [CV] END max_depth=10, max_features=0.2, min_samples_split=50; total time=   5.1s
# [CV] END max_depth=10, max_features=0.2, min_samples_split=50; total time=   5.2s
# [CV] END max_depth=20, max_features=log2, min_samples_split=2; total time=   7.8s
# [CV] END max_depth=20, max_features=log2, min_samples_split=5; total time=   7.7s
# [CV] END max_depth=20, max_features=log2, min_samples_split=10; total time=   7.4s
# [CV] END max_depth=20, max_features=log2, min_samples_split=20; total time=   7.1s
# [CV] END max_depth=20, max_features=log2, min_samples_split=20; total time=   7.1s
# [CV] END max_depth=20, max_features=log2, min_samples_split=30; total time=   6.8s
# [CV] END max_depth=20, max_features=log2, min_samples_split=40; total time=   6.6s
# [CV] END max_depth=20, max_features=log2, min_samples_split=50; total time=   6.6s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=2; total time=   7.8s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=2; total time=   7.9s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=5; total time=   7.7s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=10; total time=   7.4s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=20; total time=   7.2s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=30; total time=   6.9s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=30; total time=   6.8s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=40; total time=   6.7s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=50; total time=   6.6s
# [CV] END max_depth=20, max_features=0.1, min_samples_split=2; total time=   3.2s
# [CV] END max_depth=20, max_features=0.1, min_samples_split=2; total time=   3.2s
# [CV] END max_depth=20, max_features=0.1, min_samples_split=5; total time=   3.2s
# [CV] END max_depth=20, max_features=0.1, min_samples_split=10; total time=   3.0s
# [CV] END max_depth=20, max_features=0.1, min_samples_split=20; total time=   2.9s
# [CV] END max_depth=20, max_features=0.1, min_samples_split=30; total time=   2.8s
# [CV] END max_depth=20, max_features=0.1, min_samples_split=30; total time=   2.7s
# [CV] END max_depth=20, max_features=0.1, min_samples_split=40; total time=   2.7s
# [CV] END max_depth=20, max_features=0.1, min_samples_split=50; total time=   2.6s
# [CV] END max_depth=20, max_features=0.2, min_samples_split=2; total time=   7.8s
# [CV] END max_depth=20, max_features=0.2, min_samples_split=5; total time=   7.7s
# [CV] END max_depth=20, max_features=0.2, min_samples_split=5; total time=   7.6s
# [CV] END max_depth=20, max_features=0.2, min_samples_split=10; total time=   7.5s
# [CV] END max_depth=20, max_features=0.2, min_samples_split=20; total time=   7.0s
# [CV] END max_depth=20, max_features=0.2, min_samples_split=30; total time=   6.8s
# [CV] END max_depth=20, max_features=0.2, min_samples_split=40; total time=   6.7s
# [CV] END max_depth=20, max_features=0.2, min_samples_split=40; total time=   6.6s
# [CV] END max_depth=20, max_features=0.2, min_samples_split=50; total time=   6.5s
# [CV] END max_depth=30, max_features=log2, min_samples_split=2; total time=   8.0s
# [CV] END max_depth=30, max_features=log2, min_samples_split=5; total time=   8.0s
# [CV] END max_depth=30, max_features=log2, min_samples_split=10; total time=   7.6s
# [CV] END max_depth=30, max_features=log2, min_samples_split=10; total time=   7.5s
# [CV] END max_depth=30, max_features=log2, min_samples_split=20; total time=   7.2s
# [CV] END max_depth=30, max_features=log2, min_samples_split=30; total time=   6.9s
# [CV] END max_depth=30, max_features=log2, min_samples_split=40; total time=   6.7s
# [CV] END max_depth=30, max_features=log2, min_samples_split=50; total time=   6.6s
# [CV] END max_depth=30, max_features=log2, min_samples_split=50; total time=   6.5s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=2; total time=   8.0s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=5; total time=   7.8s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=10; total time=   7.6s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=20; total time=   7.2s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=20; total time=   7.2s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=30; total time=   6.9s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=40; total time=   6.8s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=50; total time=   6.5s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=50; total time=   6.8s
# [CV] END max_depth=30, max_features=0.1, min_samples_split=5; total time=   3.2s
# [CV] END max_depth=30, max_features=0.1, min_samples_split=10; total time=   3.1s
# [CV] END max_depth=30, max_features=0.1, min_samples_split=10; total time=   3.1s
# [CV] END max_depth=30, max_features=0.1, min_samples_split=20; total time=   3.0s
# [CV] END max_depth=30, max_features=0.1, min_samples_split=30; total time=   2.7s
# [CV] END max_depth=30, max_features=0.1, min_samples_split=40; total time=   2.7s
# [CV] END max_depth=30, max_features=0.1, min_samples_split=50; total time=   2.7s
# [CV] END max_depth=30, max_features=0.1, min_samples_split=50; total time=   2.7s
# [CV] END max_depth=30, max_features=0.2, min_samples_split=2; total time=   8.1s
# [CV] END max_depth=30, max_features=0.2, min_samples_split=5; total time=   7.8s
# [CV] END max_depth=30, max_features=0.2, min_samples_split=10; total time=   7.4s
# [CV] END max_depth=30, max_features=0.2, min_samples_split=10; total time=   7.5s
# [CV] END max_depth=30, max_features=0.2, min_samples_split=20; total time=   7.2s
# [CV] END max_depth=30, max_features=0.2, min_samples_split=30; total time=   6.9s
# [CV] END max_depth=30, max_features=0.2, min_samples_split=40; total time=   6.7s
# [CV] END max_depth=30, max_features=0.2, min_samples_split=50; total time=   6.6s
# [CV] END max_depth=30, max_features=0.1, min_samples_split=2; total time=   3.5s
# [CV] END max_depth=30, max_features=0.1, min_samples_split=5; total time=   3.2s
# [CV] END max_depth=30, max_features=0.1, min_samples_split=10; total time=   3.1s
# [CV] END max_depth=30, max_features=0.1, min_samples_split=20; total time=   2.8s
# [CV] END max_depth=30, max_features=0.1, min_samples_split=20; total time=   2.9s
# [CV] END max_depth=30, max_features=0.1, min_samples_split=30; total time=   2.8s
# [CV] END max_depth=30, max_features=0.1, min_samples_split=40; total time=   2.7s
# [CV] END max_depth=30, max_features=0.1, min_samples_split=50; total time=   2.7s
# [CV] END max_depth=30, max_features=0.2, min_samples_split=2; total time=   8.0s
# [CV] END max_depth=30, max_features=0.2, min_samples_split=2; total time=   8.0s
# [CV] END max_depth=30, max_features=0.2, min_samples_split=5; total time=   7.6s
# [CV] END max_depth=30, max_features=0.2, min_samples_split=10; total time=   7.6s
# [CV] END max_depth=30, max_features=0.2, min_samples_split=20; total time=   7.2s
# [CV] END max_depth=30, max_features=0.2, min_samples_split=30; total time=   6.9s
# [CV] END max_depth=30, max_features=0.2, min_samples_split=30; total time=   7.0s
# [CV] END max_depth=30, max_features=0.2, min_samples_split=40; total time=   6.8s
# [CV] END max_depth=30, max_features=0.2, min_samples_split=50; total time=   5.9s
# [CV] END max_depth=30, max_features=0.1, min_samples_split=5; total time=   3.2s
# [CV] END max_depth=30, max_features=0.1, min_samples_split=10; total time=   3.1s
# [CV] END max_depth=30, max_features=0.1, min_samples_split=20; total time=   2.9s
# [CV] END max_depth=30, max_features=0.1, min_samples_split=20; total time=   2.9s
# [CV] END max_depth=30, max_features=0.1, min_samples_split=30; total time=   2.8s
# [CV] END max_depth=30, max_features=0.1, min_samples_split=40; total time=   2.7s
# [CV] END max_depth=30, max_features=0.1, min_samples_split=50; total time=   2.7s
# [CV] END max_depth=30, max_features=0.2, min_samples_split=2; total time=   7.9s
# [CV] END max_depth=30, max_features=0.2, min_samples_split=2; total time=   8.1s
# [CV] END max_depth=30, max_features=0.2, min_samples_split=5; total time=   7.8s
# [CV] END max_depth=30, max_features=0.2, min_samples_split=10; total time=   7.5s
# [CV] END max_depth=30, max_features=0.2, min_samples_split=20; total time=   7.2s
# [CV] END max_depth=30, max_features=0.2, min_samples_split=30; total time=   6.9s
# [CV] END max_depth=30, max_features=0.2, min_samples_split=30; total time=   6.9s
# [CV] END max_depth=30, max_features=0.2, min_samples_split=40; total time=   6.7s
# [CV] END max_depth=30, max_features=0.2, min_samples_split=50; total time=   5.9s
# [CV] END max_depth=30, max_features=0.1, min_samples_split=5; total time=   3.1s
# [CV] END max_depth=30, max_features=0.1, min_samples_split=10; total time=   3.0s
# [CV] END max_depth=30, max_features=0.1, min_samples_split=20; total time=   2.9s
# [CV] END max_depth=30, max_features=0.1, min_samples_split=30; total time=   2.8s
# [CV] END max_depth=30, max_features=0.1, min_samples_split=30; total time=   2.8s
# [CV] END max_depth=30, max_features=0.1, min_samples_split=40; total time=   2.7s
# [CV] END max_depth=30, max_features=0.1, min_samples_split=50; total time=   2.7s
# [CV] END max_depth=30, max_features=0.2, min_samples_split=2; total time=   8.1s
# [CV] END max_depth=30, max_features=0.2, min_samples_split=5; total time=   7.8s
# [CV] END max_depth=30, max_features=0.2, min_samples_split=5; total time=   7.9s
# [CV] END max_depth=30, max_features=0.2, min_samples_split=10; total time=   7.6s
# [CV] END max_depth=30, max_features=0.2, min_samples_split=20; total time=   7.2s
# [CV] END max_depth=30, max_features=0.2, min_samples_split=30; total time=   6.9s
# [CV] END max_depth=30, max_features=0.2, min_samples_split=40; total time=   6.7s
# [CV] END max_depth=30, max_features=0.2, min_samples_split=40; total time=   6.7s
# [CV] END max_depth=30, max_features=0.2, min_samples_split=50; total time=   5.8s
# [CV] END max_depth=30, max_features=0.1, min_samples_split=5; total time=   3.3s
# [CV] END max_depth=30, max_features=0.1, min_samples_split=10; total time=   3.1s
# [CV] END max_depth=30, max_features=0.1, min_samples_split=10; total time=   3.1s
# [CV] END max_depth=30, max_features=0.1, min_samples_split=20; total time=   2.8s
# [CV] END max_depth=30, max_features=0.1, min_samples_split=30; total time=   2.8s
# [CV] END max_depth=30, max_features=0.1, min_samples_split=40; total time=   2.7s
# [CV] END max_depth=30, max_features=0.1, min_samples_split=50; total time=   2.6s
# [CV] END max_depth=30, max_features=0.1, min_samples_split=50; total time=   2.6s
# [CV] END max_depth=30, max_features=0.2, min_samples_split=2; total time=   7.9s
# [CV] END max_depth=30, max_features=0.2, min_samples_split=5; total time=   7.9s
# [CV] END max_depth=30, max_features=0.2, min_samples_split=10; total time=   7.6s
# [CV] END max_depth=30, max_features=0.2, min_samples_split=20; total time=   7.2s
# [CV] END max_depth=30, max_features=0.2, min_samples_split=20; total time=   7.3s
# [CV] END max_depth=30, max_features=0.2, min_samples_split=30; total time=   6.9s
# [CV] END max_depth=30, max_features=0.2, min_samples_split=40; total time=   6.7s
# [CV] END max_depth=30, max_features=0.2, min_samples_split=50; total time=   6.5s
# [CV] END max_depth=30, max_features=0.2, min_samples_split=50; total time=   5.8s
# [CV] END max_depth=30, max_features=0.1, min_samples_split=5; total time=   3.2s
# [CV] END max_depth=30, max_features=0.1, min_samples_split=10; total time=   3.1s
# [CV] END max_depth=30, max_features=0.1, min_samples_split=20; total time=   2.9s
# [CV] END max_depth=30, max_features=0.1, min_samples_split=30; total time=   2.8s
# [CV] END max_depth=30, max_features=0.1, min_samples_split=30; total time=   2.8s
# [CV] END max_depth=30, max_features=0.1, min_samples_split=40; total time=   2.7s
# [CV] END max_depth=30, max_features=0.1, min_samples_split=50; total time=   2.6s
# [CV] END max_depth=30, max_features=0.2, min_samples_split=2; total time=   8.0s
# [CV] END max_depth=30, max_features=0.2, min_samples_split=5; total time=   7.8s
# [CV] END max_depth=30, max_features=0.2, min_samples_split=5; total time=   8.0s
# [CV] END max_depth=30, max_features=0.2, min_samples_split=10; total time=   7.7s
# [CV] END max_depth=30, max_features=0.2, min_samples_split=20; total time=   7.3s
# [CV] END max_depth=30, max_features=0.2, min_samples_split=30; total time=   7.0s
# [CV] END max_depth=30, max_features=0.2, min_samples_split=40; total time=   6.7s
# [CV] END max_depth=30, max_features=0.2, min_samples_split=50; total time=   6.6s
# [CV] END max_depth=30, max_features=0.2, min_samples_split=50; total time=   5.8s
# [CV] END max_depth=30, max_features=0.1, min_samples_split=5; total time=   3.3s
# [CV] END max_depth=30, max_features=0.1, min_samples_split=5; total time=   3.3s
# [CV] END max_depth=30, max_features=0.1, min_samples_split=10; total time=   3.1s
# [CV] END max_depth=30, max_features=0.1, min_samples_split=20; total time=   3.1s
# [CV] END max_depth=30, max_features=0.1, min_samples_split=30; total time=   2.8s
# [CV] END max_depth=30, max_features=0.1, min_samples_split=40; total time=   2.7s
# [CV] END max_depth=30, max_features=0.1, min_samples_split=40; total time=   2.7s
# [CV] END max_depth=30, max_features=0.1, min_samples_split=50; total time=   2.6s
# [CV] END max_depth=30, max_features=0.2, min_samples_split=2; total time=   7.9s
# [CV] END max_depth=30, max_features=0.2, min_samples_split=5; total time=   7.8s
# [CV] END max_depth=30, max_features=0.2, min_samples_split=10; total time=   7.5s
# [CV] END max_depth=30, max_features=0.2, min_samples_split=10; total time=   7.6s
# [CV] END max_depth=30, max_features=0.2, min_samples_split=20; total time=   7.2s
# [CV] END max_depth=30, max_features=0.2, min_samples_split=30; total time=   6.9s
# [CV] END max_depth=30, max_features=0.2, min_samples_split=40; total time=   6.8s
# [CV] END max_depth=30, max_features=0.2, min_samples_split=40; total time=   6.7s
# [CV] END max_depth=30, max_features=0.2, min_samples_split=50; total time=   5.8s

# %%
rf.fit(X=X_train_pca, y=train_labels_encoded)

train_pred = rf.predict(X_train_pca)
print(classification_report(train_labels_encoded, train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      3995
#            1       1.00      0.86      0.93       436
#            2       0.99      0.97      0.98      4097
#            3       0.99      1.00      0.99      7215
#            4       0.98      0.98      0.98      4965
#            5       1.00      1.00      1.00      4830
#            6       0.96      0.97      0.96      3171
#
#     accuracy                           0.98     28709
#    macro avg       0.99      0.97      0.98     28709
# weighted avg       0.98      0.98      0.98     28709

# %%
#Gabor PCA + mediapipe PCA + RF
